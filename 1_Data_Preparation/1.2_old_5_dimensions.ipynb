# %%
import numpy as np
import re
import pandas as pd
import pickle
from collections import Counter
from openpyxl import Workbook
from openpyxl import load_workbook

# %% [markdown]
# # Excelのdata
# - A_W_171116
#   - excelの行番号1～299行目までのデータを使用
# - A_W_171121
#   - excelの行番号300～末尾行目までのデータを使用
# - S_H_171116
#   - A_W_YYMMDDとは別の人たちが作成したexcelデータ
# - 斎藤_2015
#   - S_H_1116の破損しているreply列のデータを修復するためのファイル

# %%
dirpath = "../data/excel/"

filename = "A_W_171116.xlsx"
A_W_171116_excel = pd.ExcelFile(dirpath + filename)
sheet_name = A_W_171116_excel.sheet_names[0]
A_W_171116_df = A_W_171116_excel.parse(sheet_name)

filename = "A_W_171128.xlsx"
A_W_171128_excel = pd.ExcelFile(dirpath + filename)
sheet_name = A_W_171128_excel.sheet_names[0]
A_W_171128_df = A_W_171128_excel.parse(sheet_name)

filename = "171116.xlsx"
S_H_171116_excel = pd.ExcelFile(dirpath + filename)
sheet_name = S_H_171116_excel.sheet_names[0]
S_H_171116_df = S_H_171116_excel.parse(sheet_name)

filename = "2015斉藤.xlsx"
S_2015_excel = pd.ExcelFile(dirpath + filename)
sheet_name = S_2015_excel.sheet_names[0]
S_2015_df = S_2015_excel.parse(sheet_name)

# %% [markdown]
# ## 必要なデータ
# - id
#     - A_W_YYMMDDのNo. => (0列目)
#     - SH_171116のid => (0列目)
#     - 斉藤2015の発言番号 => (0列目)
# - reply
#     - A_W_YYMMDDの返信元 => (1列目)
#     - SH_171116のreply => (3列目)
#     - 斉藤2015の返信元 => (1列目)
# - group
#     - A_W_YYMMDDのgid => (6列目)
#     - SH_171116のgid => (5列目)
#     - 斉藤2015のグループ番号 => (6列目)
# - who
#     - A_W_YYMMDDのニックネーム => (8列目)
#     - SH_171116のcname => (6列目)
#     - 斉藤2015のニックネーム => (8列目)
# - body
#     - A_W_YYMMDDの発言内容 => (11列目)
#     - SH_171116のbody => (8列目)
#     - 斉藤2015の発言内容 => (11列目)
# - argumentation_a
#     - A_W_YYMMDDのArgumentation(A) => (22列目)
#     - SH_171116のArgumentation(H) => (17列目)
# - argumentation_b
#     - A_W_YYMMDDのWatanabe.2 => (23列目)
#     - SH_171116のArgumentation(S) => (18列目)
# - epistemic_a
#     - A_W_YYMMDDのEpistemic(A) => (12列目)
#     - SH_171116のEpistemic(H) => (9列目)
# - epistemic_b
#     - A_W_YYMMDDのWatanabe => (13列目)
#     - SH_171116のEpistemic(S) => (10列目)
# - social_table_a
#     - A_W_YYMMDDのSocial(A) => (27列目)
#     - SH_171116のSocial(H) => (21列目)
# - social_table_b
#     - A_W_YYMMDDのWatanabe.3 => (28列目)
#     - SH_171116のSocial(S) => (22列目)
# - coordination_a
#     - A_W_YYMMDDのCoordination(A) => (17列目)
#     - SH_171116のCoordination(H) => (13列目)
# - coordination_b
#     - A_W_YYMMDDのWatanabe.1 => (18列目)
#     - SH_171116のCoordination(S) => (14列目)
#
#
# ## 各dfで必要な列
# - A_W_YYMMDD[0, 1, 6, 8, 11, 22, 23, 12, 13, 27, 28, 17, 18]
# - SH_171116[0, 3, 5, 6, 8, 17, 18, 9, 10, 21, 22, 13, 14]
# - 斉藤2015[0, 1, 6, 8, 11]

# %%
A_W_YYMMDD_use = [0, 1, 6, 8, 11, 22, 23, 12, 13, 27, 28, 17, 18]
S_H_171116_use = [0, 3, 5, 6, 8, 17, 18, 9, 10, 21, 22, 13, 14]
S_2015_use = [0, 1, 6, 8, 11]

# %% [markdown]
# ## 使用しない列の削除

# %%
# A_W_YYMMDDの列名の統合
A_W_171116_df.columns = A_W_171128_df.columns

delete_columns_list = []
for i, column in enumerate(A_W_171116_df):
    if not i in A_W_YYMMDD_use:
        delete_columns_list.append(column)

A_W_171116_df = A_W_171116_df.drop(delete_columns_list, axis=1)
A_W_171128_df = A_W_171128_df.drop(delete_columns_list, axis=1)

delete_columns_list = []
for i, column in enumerate(S_H_171116_df):
    if not i in S_H_171116_use:
        delete_columns_list.append(column)
S_H_171116_df = S_H_171116_df.drop(delete_columns_list, axis=1)

delete_columns_list = []
for i, column in enumerate(S_2015_df):
    if not i in S_2015_use:
        delete_columns_list.append(column)
S_2015_df = S_2015_df.drop(delete_columns_list, axis=1)

# %%
A_W_171116_df.head(3)
# Out:
#    No. 返信元  gid ニックネーム                          発言内容 Epistemic(A)  Watanabe  \
# 0    1  \N    1   まこぴす                   よろしくお願いします！     Off task  Off Task
# 1   31  \N    1      哲                    よろしくお願いします     Off task  Off Task
# 2   70  \N    1     仙波  名前なのが恥ずかしいです…\n\nよろしくお願いします！     Off task  Off Task
#
#   Coordination(A) Watanabe.1         Argumentation(A)  \
# 0             NaN        NaN  Non-argumentative moves
# 1             NaN        NaN  Non-argumentative moves
# 2             NaN        NaN  Non-argumentative moves
#
#                 Watanabe.2 Social(A) Watanabe.3
# 0  Non-argumentative moves       NaN        NaN
# 1  Non-argumentative moves       NaN        NaN
# 2  Non-argumentative moves       NaN        NaN

# %%
A_W_171128_df.head(3)
# Out:
#     No. 返信元  gid ニックネーム                          発言内容 Epistemic(A)  Watanabe  \
# 0   1.0  \N  1.0   まこぴす                   よろしくお願いします！     Off task  Off Task
# 1  31.0  \N  1.0      哲                    よろしくお願いします     Off task  Off Task
# 2  70.0  \N  1.0     仙波  名前なのが恥ずかしいです…\n\nよろしくお願いします！     Off task  Off Task
#
#   Coordination(A) Watanabe.1         Argumentation(A)  \
# 0             NaN        NaN  Non-argumentative moves
# 1             NaN        NaN  Non-argumentative moves
# 2             NaN        NaN  Non-argumentative moves
#
#                 Watanabe.2 Social(A) Watanabe.3
# 0  Non-argumentative moves       NaN        NaN
# 1  Non-argumentative moves       NaN        NaN
# 2  Non-argumentative moves       NaN        NaN

# %%
S_H_171116_df.head(3)
# Out:
#      id  reply  gid   cname         body Epistemic(H) Epistemic(S)  \
# 0  1593      2    2  世界のわたべ  よろしくお願いします。     Off Task     Off Task
# 1  1598      2    3    ざきさん       よろしくです     Off Task     Off Task
# 2  1606      2   56       あ       よろしくです     Off Task     Off Task
#
#   Coordination(H) Coordination(S)         Argumentation(H)  \
# 0             NaN             NaN  Non-argumentative moves
# 1             NaN             NaN  Non-argumentative moves
# 2             NaN             NaN  Non-argumentative moves
#
#           Argumentation(S) Social(H) Social(S)
# 0  Non-argumentative moves       NaN       NaN
# 1  Non-argumentative moves       NaN       NaN
# 2  Non-argumentative moves       NaN       NaN

# %%
S_2015_df.head(3)
# Out:
#    発言番号 返信元  グループ番号  ニックネーム         発言内容
# 0  1593  \N       1  世界のわたべ  よろしくお願いします。
# 1  1598  \N       1    ざきさん       よろしくです
# 2  1606  \N       1       あ       よろしくです

# %% [markdown]
# ## データの一致の確認

# %%
print(not False in S_H_171116_df['id'].values == S_2015_df['発言番号'].values)
print(not False in S_H_171116_df['cname'].values == S_2015_df['ニックネーム'].values)
print(not False in S_H_171116_df['body'].values == S_2015_df['発言内容'].values)
print(A_W_171116_df.shape)
print(A_W_171128_df.shape)
print(S_H_171116_df.shape)
print(S_2015_df.shape)
# Out:
# True
# True
# True
# (4943, 13)
# (4945, 13)
# (5017, 13)
# (5017, 5)

# %% [markdown]
# ## 欠損データの置換とA_W_YYMMDDの結合

# %%
S_H_171116_df["reply"] = S_2015_df['返信元']
S_H_171116_df["gid"] = S_2015_df['グループ番号']
concat_border = 299
A_W_171116_df = A_W_171116_df[0:concat_border]
A_W_171128_df = A_W_171128_df[concat_border:]
A_W_df = pd.concat([A_W_171116_df, A_W_171128_df])
print(A_W_df.shape)
print(S_H_171116_df.shape)
# Out:
# (4945, 13)
# (5017, 13)

# %% [markdown]
# ## 列名の統一

# %%
col = [
    'say_id', 'reply_id', 'group_id', 'name', 'body', 'epistemic_a',
    'epistemic_b', 'coordination_a', 'coordination_b', 'argument_a',
    'argument_b', 'social_a', 'social_b'
]

A_W_df = pd.DataFrame(A_W_df.values, columns=col)
S_H_171116_df = pd.DataFrame(S_H_171116_df.values, columns=col)

# %%
A_W_df
# Out:
#      say_id reply_id group_id     name  \
# 0         1       \N        1     まこぴす
# 1        31       \N        1        哲
# 2        70       \N        1       仙波
# 3       119       \N        1     まこぴす
# 4       163       \N        1       仙波
# 5       194       \N        1     まこぴす
# 6       302       \N        1        哲
# 7       309       \N        1       仙波
# 8       385       \N        1     まこぴす
# 9       426       \N        1     まこぴす
# 10      500       \N        1       仙波
# 11      528       \N        1       仙波
# 12      693       \N        1     まこぴす
# 13      715       \N        1       仙波
# 14      746       \N        1     まこぴす
# 15      791       \N        1       仙波
# 16      813       \N        1     まこぴす
# 17      830      746        1        哲
# 18      831       \N        1       仙波
# 19      851      813        1        哲
# 20      888       \N        1       仙波
# 21      899       \N        1     まこぴす
# 22      916       \N        1       仙波
# 23      934      899        1        哲
# 24      964       \N        1     まこぴす
# 25      990       \N        1       仙波
# 26     1017       \N        1       \N
# 27     1031       \N        1     まこぴす
# 28     1048       \N        1       仙波
# 29     1066       \N        1        哲
# ...     ...      ...      ...      ...
# 4915   3963       \N     1004  だいきでかいと
# 4916   3982       \N     1004       星矢
# 4917   4009       \N     1004       星矢
# 4918   4017     4009     1004  だいきでかいと
# 4919   4038       \N     1004       星矢
# 4920   4086     4038     1004  だいきでかいと
# 4921   4111       \N     1004       星矢
# 4922   4134     4111     1004  だいきでかいと
# 4923   4147       \N     1004  だいきでかいと
# 4924   4160       \N     1004       星矢
# 4925   4171       \N     1004  だいきでかいと
# 4926   4196       \N     1004  だいきでかいと
# 4927   4207       \N     1004       星矢
# 4928   4219       \N     1004       星矢
# 4929   4224     4207     1004  だいきでかいと
# 4930   4245       \N     1004  だいきでかいと
# 4931   4264     4245     1004       星矢
# 4932   4303       \N     1004  だいきでかいと
# 4933   4329       \N     1004  だいきでかいと
# 4934   4372       \N     1004       星矢
# 4935   4377       \N     1004  だいきでかいと
# 4936   4392     4377     1004       星矢
# 4937   4401     4392     1004  だいきでかいと
# 4938   4453     4401     1004       星矢
# 4939   4464       \N     1004  だいきでかいと
# 4940   3805       \N     1005       モブ
# 4941   4088       \N     1005       モブ
# 4942   4505       \N     1005       モブ
# 4943   4921       \N     1005       モブ
# 4944    NaN      NaN      NaN      NaN
#
#                                                    body epistemic_a  \
# 0                                           よろしくお願いします！    Off task
# 1                                            よろしくお願いします    Off task
# 2                          名前なのが恥ずかしいです…\n\nよろしくお願いします！    Off task
# 3                                        早速課題やっちゃいましょう！    Off task
# 4                             やっちゃいましょう\n\nmoodleはゴミです！     On task
# 5                                            使いにくいです(笑)     On task
# 6                                                  同意です     On task
# 7     以前インタラクティブアート受講していたのですが、その時に課題が不具合で出せなくなっていた時期...     On task
# 8     学習環境として必要最低限の機能は備えていると思うが、操作性の面ではPCの最低限の知識があるこ...     On task
# 9                                           自分の意見です！(笑)    Off task
# 10                                             ほぼほぼ同意です     On task
# 11                                    他に何か考えてることなどありますか     On task
# 12                                          他に意見ありますかー？     On task
# 13                                              自分はないです     On task
# 14                                            哲さんどうですか？     On task
# 15                  まこびすさんがいい感じにまとめてくれたので自分はこれでいいと思います！     On task
# 16                             １度共有テキスト全部消して現在の回答案書きます！    Off task
# 17                       > 哲さんどうですか？\n\n自分もみなさんの意見に同意です     On task
# 18                                                 了解です     On task
# 19                                           ありがとうございます    Off task
# 20                                    あざっす\n\nこれでいいのでは？    Off task
# 21                      こちらの回答案でよければ課題回答しちゃいますけど大丈夫ですか？    Off task
# 22                                              自分は平気です    Off task
# 23                                          よろしくお願いします！    Off task
# 24                                                完了です！    Off task
# 25                                              お疲れ様です！    Off task
# 26                                           １番乗りおめでとう！    Off task
# 27                                        ありがとうございます(笑)    Off task
# 28                                                  でた！    Off task
# 29                       お役に立てず申し訳ございません\n\nありがとうごいました！    Off task
# ...                                                 ...         ...
# 4915               それかあえて、子供を対象者から外して、親に対するものにするものありかも。     On Task
# 4916                                  本当は怖い　～ターゲットは我が子～     On Task
# 4917                      でも使うのは子供だから子供を外すのはちょっと違ってくるよね     On Task
# 4918            > でも使うのは子供だから子供を外すのはちょっと違ってくるよね\n\n確かに。     On Task
# 4919                                まさかの一番の悩みがタイトルっていう…     On Task
# 4920                   > まさかの一番の悩みがタイトルっていう…\n\nそれ。\n\n     On Task
# 4921                                タイトル作ってみたけどこれでいいかな？     On Task
# 4922  > タイトル作ってみたけどこれでいいかな？\n\nいきましょう\n\nそれで。\n\n私めは...     On Task
# 4923                                              亭主TUー    No Sense
# 4924                                 もうちょっと工夫点・特徴点ないかな？     On Task
# 4925                                 考えますか。\n\nうーん。\n\n    Off Task
# 4926                                          おやこ登場\n\n     On Task
# 4927                                        モザイク・変声必至だな     On Task
# 4928                                     データ放送使えないだろうか？     On Task
# 4929                  > モザイク・変声必至だな\n\n間違いない。スモークの衝立必要。     On Task
# 4930                        使えそう。\n\n質問項目を設けるか。\n\nクイズ？     On Task
# 4931  > 使えそう。\n\n\n\n> 質問項目を設けるか。\n\n\n\n> クイズ？\n\n\...     On Task
# 4932                             クイズ正解者にはウィルスソフトプレゼントー！     On Task
# 4933                                    他にはなにかあるかな；\n\n    Off Task
# 4934                                  何も出てこない\n\nネタが尽きた     On Task
# 4935                              これちなみにこの一つ提出したら良いのよね？    Off Task
# 4936                > これちなみにこの一つ提出したら良いのよね？\n\n\n\nそうだよ    Off Task
# 4937  > &gt; これちなみにこの一つ提出したら良いのよね？\n\n> そうだよ\n\n\n\n...    Off Task
# 4938  > &gt; &gt; これちなみにこの一つ提出したら良いのよね？\n\n\n\n> &gt...    Off Task
# 4939                                              おっつん。    Off Task
# 4940                                       よろしくおねがいします。    Off Task
# 4941                              なにか新しい教育番組の案などありませんか？    Off Task
# 4942            対象者:Englishというのは外国の方が対象者ということでよいのでしょうか？     On Task
# 4943                              回答出していただいてありがとうございます。    Off Task
# 4944                                                NaN         NaN
#
#      epistemic_b          coordination_a          coordination_b  \
# 0       Off Task                     NaN                     NaN
# 1       Off Task                     NaN                     NaN
# 2       Off Task                     NaN                     NaN
# 3       Off Task             Proceedings             Proceedings
# 4        On Task                     NaN                     NaN
# 5        On Task                     NaN                     NaN
# 6        On Task                     NaN                     NaN
# 7        On Task                     NaN                     NaN
# 8        On Task                     NaN                     NaN
# 9        On Task                     NaN                     NaN
# 10       On Task                     NaN                     NaN
# 11       On Task                     NaN                     NaN
# 12       On Task                     NaN                     NaN
# 13       On Task                     NaN                     NaN
# 14      Off Task                     NaN             Proceedings
# 15       On Task                     NaN                     NaN
# 16      Off Task  Technical coordination  Technical coordination
# 17       On Task                     NaN                     NaN
# 18       On Task                     NaN                     NaN
# 19       On Task                     NaN                     NaN
# 20       On Task                     NaN                     NaN
# 21      Off Task             Proceedings  Technical coordination
# 22      Off Task                     NaN                     NaN
# 23      Off Task                     NaN                     NaN
# 24      Off Task  Technical coordination  Technical coordination
# 25      Off Task                     NaN                     NaN
# 26      Off Task                     NaN                     NaN
# 27      Off Task                     NaN                     NaN
# 28      Off Task                     NaN                     NaN
# 29      Off Task                     NaN                     NaN
# ...          ...                     ...                     ...
# 4915     On Task                     NaN                     NaN
# 4916     On Task                     NaN                     NaN
# 4917     On Task                     NaN                     NaN
# 4918     On Task                     NaN                     NaN
# 4919    Off Task                     NaN                     NaN
# 4920    Off Task                     NaN                     NaN
# 4921    Off Task                     NaN                     NaN
# 4922    Off Task                     NaN                     NaN
# 4923    Off Task                     NaN                     NaN
# 4924    Off Task                     NaN             Proceedings
# 4925    Off Task           Task division                     NaN
# 4926     On Task                     NaN                     NaN
# 4927     On Task                     NaN                     NaN
# 4928     On Task                     NaN                     NaN
# 4929     On Task                     NaN                     NaN
# 4930     On Task                     NaN                     NaN
# 4931     On Task                     NaN                     NaN
# 4932     On Task                     NaN                     NaN
# 4933    Off Task             Proceedings                     NaN
# 4934    Off Task                     NaN                     NaN
# 4935    Off Task           Task division  Technical coordination
# 4936    Off Task           Task division                     NaN
# 4937    Off Task         Time management                     NaN
# 4938    Off Task                     NaN                     NaN
# 4939    Off Task                     NaN                     NaN
# 4940    Off Task                     NaN                     NaN
# 4941    Off Task             Proceedings             Proceedings
# 4942     On Task                     NaN                     NaN
# 4943    Off Task                     NaN  Technical coordination
# 4944         NaN                     NaN                     NaN
#
#                         argument_a                    argument_b  \
# 0          Non-argumentative moves       Non-argumentative moves
# 1          Non-argumentative moves       Non-argumentative moves
# 2          Non-argumentative moves       Non-argumentative moves
# 3          Non-argumentative moves       Non-argumentative moves
# 4                     Simple claim                  Simple Claim
# 5                     Simple claim                  Simple Claim
# 6                     Simple claim                  Simple Claim
# 7                   Grounded claim                Grounded Claim
# 8     Grounded and Qualified claim  Grounded and Qualified claim
# 9          Non-argumentative moves                  Simple Claim
# 10                    Simple claim                  Simple Claim
# 11         Non-argumentative moves       Non-argumentative moves
# 12         Non-argumentative moves       Non-argumentative moves
# 13         Non-argumentative moves                  Simple Claim
# 14         Non-argumentative moves       Non-argumentative moves
# 15                  Grounded claim                  Simple Claim
# 16         Non-argumentative moves       Non-argumentative moves
# 17                    Simple claim                  Simple Claim
# 18         Non-argumentative moves                  Simple Claim
# 19         Non-argumentative moves                  Simple Claim
# 20         Non-argumentative moves                  Simple Claim
# 21         Non-argumentative moves       Non-argumentative moves
# 22         Non-argumentative moves       Non-argumentative moves
# 23         Non-argumentative moves       Non-argumentative moves
# 24         Non-argumentative moves       Non-argumentative moves
# 25         Non-argumentative moves       Non-argumentative moves
# 26         Non-argumentative moves       Non-argumentative moves
# 27         Non-argumentative moves       Non-argumentative moves
# 28         Non-argumentative moves       Non-argumentative moves
# 29         Non-argumentative moves       Non-argumentative moves
# ...                            ...                           ...
# 4915                  Simple Claim                  Simple Claim
# 4916                  Simple Claim                  Simple Claim
# 4917                Grounded Claim                  Simple Claim
# 4918                  Simple Claim                  Simple Claim
# 4919                  Simple Claim       Non-argumentative moves
# 4920                  Simple Claim       Non-argumentative moves
# 4921       Non-argumentative moves       Non-argumentative moves
# 4922                Grounded Claim       Non-argumentative moves
# 4923                           NaN       Non-argumentative moves
# 4924       Non-argumentative moves       Non-argumentative moves
# 4925       Non-argumentative moves       Non-argumentative moves
# 4926                  Simple Claim                  Simple Claim
# 4927                  Simple Claim                  Simple Claim
# 4928                  Simple Claim                  Simple Claim
# 4929                  Simple Claim                  Simple Claim
# 4930                  Simple Claim                  Simple Claim
# 4931                  Simple Claim                  Simple Claim
# 4932                  Simple Claim                  Simple Claim
# 4933       Non-argumentative moves       Non-argumentative moves
# 4934                  Simple Claim       Non-argumentative moves
# 4935       Non-argumentative moves       Non-argumentative moves
# 4936       Non-argumentative moves       Non-argumentative moves
# 4937       Non-argumentative moves       Non-argumentative moves
# 4938       Non-argumentative moves       Non-argumentative moves
# 4939       Non-argumentative moves       Non-argumentative moves
# 4940       Non-argumentative moves       Non-argumentative moves
# 4941       Non-argumentative moves       Non-argumentative moves
# 4942       Non-argumentative moves       Non-argumentative moves
# 4943       Non-argumentative moves       Non-argumentative moves
# 4944                           NaN                           NaN
#
#                                   social_a  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                          Externalization
# 5                          Externalization
# 6                 Quick consensus building
# 7                          Externalization
# 8                          Externalization
# 9                                      NaN
# 10                Quick consensus building
# 11                             Elicitation
# 12                             Elicitation
# 13                Quick consensus building
# 14                             Elicitation
# 15                         Externalization
# 16                                     NaN
# 17                Quick consensus building
# 18                Quick consensus building
# 19                                     NaN
# 20                                     NaN
# 21                                     NaN
# 22                                     NaN
# 23                                     NaN
# 24                                     NaN
# 25                                     NaN
# 26                                     NaN
# 27                                     NaN
# 28                                     NaN
# 29                                     NaN
# ...                                    ...
# 4915                       Externalization
# 4916                                   NaN
# 4917  Conflict-oriented consensus building
# 4918              Quick consensus building
# 4919                       Externalization
# 4920              Quick consensus building
# 4921                           Elicitation
# 4922              Quick consensus building
# 4923                                   NaN
# 4924                           Elicitation
# 4925                                   NaN
# 4926                       Externalization
# 4927                                   NaN
# 4928                       Externalization
# 4929              Quick consensus building
# 4930                                   NaN
# 4931              Quick consensus building
# 4932                       Externalization
# 4933                                   NaN
# 4934                                   NaN
# 4935                                   NaN
# 4936                                   NaN
# 4937                                   NaN
# 4938                                   NaN
# 4939                                   NaN
# 4940                                   NaN
# 4941                                   NaN
# 4942                           Elicitation
# 4943                                   NaN
# 4944                                   NaN
#
#                                      social_b
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                    Quick consensus building
# 7                             Externalization
# 8                             Externalization
# 9                             Externalization
# 10                   Quick consensus building
# 11                                Elicitation
# 12                                Elicitation
# 13                            Externalization
# 14                                        NaN
# 15                   Quick consensus building
# 16                                        NaN
# 17                   Quick consensus building
# 18                   Quick consensus building
# 19                   Quick consensus building
# 20                   Quick consensus building
# 21                                        NaN
# 22                                        NaN
# 23                                        NaN
# 24                                        NaN
# 25                                        NaN
# 26                                        NaN
# 27                                        NaN
# 28                                        NaN
# 29                                        NaN
# ...                                       ...
# 4915  Integrarion-oriented consensus building
# 4916                          Externalization
# 4917     Conflict-oriented consensus building
# 4918                 Quick consensus building
# 4919                                      NaN
# 4920                                      NaN
# 4921                                      NaN
# 4922                                      NaN
# 4923                                      NaN
# 4924                                      NaN
# 4925                                      NaN
# 4926                          Externalization
# 4927                 Quick consensus building
# 4928                          Externalization
# 4929                 Quick consensus building
# 4930  Integrarion-oriented consensus building
# 4931                 Quick consensus building
# 4932                          Externalization
# 4933                                      NaN
# 4934                                      NaN
# 4935                                      NaN
# 4936                                      NaN
# 4937                                      NaN
# 4938                                      NaN
# 4939                                      NaN
# 4940                                      NaN
# 4941                                      NaN
# 4942                              Elicitation
# 4943                                      NaN
# 4944                                      NaN
#
# [4945 rows x 13 columns]

# %%
S_H_171116_df
# Out:
#      say_id reply_id group_id    name  \
# 0      1593       \N        1  世界のわたべ
# 1      1598       \N        1    ざきさん
# 2      1606       \N        1       あ
# 3      1659       \N        1    ざきさん
# 4      1683       \N        1       あ
# 5      1692       \N        1  世界のわたべ
# 6      1704       \N        1    ざきさん
# 7      1794       \N        1    ざきさん
# 8      1821       \N        1       あ
# 9      1914       \N        1  世界のわたべ
# 10     1926       \N        1    ざきさん
# 11     2102       \N        1  世界のわたべ
# 12     2103       \N        1  世界のわたべ
# 13     2157     2103        1    ざきさん
# 14     2172     2157        1  世界のわたべ
# 15     2274       \N        1  世界のわたべ
# 16     2455     2274        1       あ
# 17     2482     2455        1  世界のわたべ
# 18     2500       \N        1    ざきさん
# 19     2509     2500        1  世界のわたべ
# 20     2552       \N        1    ざきさん
# 21     2653       \N        1  世界のわたべ
# 22     2687     2653        1    ざきさん
# 23     2740       \N        1  世界のわたべ
# 24     2772       \N        1  世界のわたべ
# 25     2792     2772        1    ざきさん
# 26     2809       \N        1  世界のわたべ
# 27     2900       \N        1  世界のわたべ
# 28     2947     2809        1    ざきさん
# 29     2959       \N        1    ざきさん
# ...     ...      ...      ...     ...
# 4987   6241     6224    10001     まささ
# 4988   6243       \N    10001    オノヅカ
# 4989   6254       \N    10001    オノヅカ
# 4990   6257     6254    10001     まささ
# 4991   6264     6254    10001     みずき
# 4992   6266       \N    10001    オノヅカ
# 4993   6278     6266    10001     まささ
# 4994   6280     6266    10001     みずき
# 4995   6288       \N    10001    オノヅカ
# 4996   6326       \N    10001    オノヅカ
# 4997   6347       \N    10001     みずき
# 4998   6363       \N    10001     まささ
# 4999   6388       \N    10001    オノヅカ
# 5000   6397       \N    10001    オノヅカ
# 5001   6404     6388    10001     みずき
# 5002   6410     6404    10001    オノヅカ
# 5003   6415       \N    10001     まささ
# 5004   6419     6404    10001     まささ
# 5005   6435     6415    10001     みずき
# 5006   6436       \N    10001    オノヅカ
# 5007   6441     6436    10001     みずき
# 5008   6443     6436    10001     まささ
# 5009   6449       \N    10001    オノヅカ
# 5010   6451     6443    10001     みずき
# 5011   6459       \N    10001     みずき
# 5012   6463     6459    10001     まささ
# 5013   6467     6459    10001    オノヅカ
# 5014   6477       \N    10001    オノヅカ
# 5015   6491     6477    10001     まささ
# 5016   6521       \N    10001    オノヅカ
#
#                                                    body epistemic_a  \
# 0                                           よろしくお願いします。    Off Task
# 1                                                よろしくです    Off Task
# 2                                                よろしくです    Off Task
# 3                                    みなさんファイルをアップしましたか？    Off Task
# 4                                             今アップしました！    Off Task
# 5                                             今アップしました！    Off Task
# 6                                                名前バレｗｗ    Off Task
# 7                                              質問特にないです    Off Task
# 8                                             同じく特に無いです    Off Task
# 9                                                 いますよー    Off Task
# 10                                        宿題の批評、終わりました。    Off Task
# 11    「いのちの創造」とは、生命に対する言葉ですか？もしくは絵とか作品に命を吹き込むという意味の言...     On Task
# 12    「いのちの創造」とは、生命に対する言葉ですか？もしくは絵とか作品に命を吹き込むという意味の言...    No Sense
# 13    > 「いのちの創造」とは、生命に対する言葉ですか？もしくは絵とか作品に命を吹き込むという意味...     On Task
# 14    > &gt; 「いのちの創造」とは、生命に対する言葉ですか？もしくは絵とか作品に命を吹き込む...     On Task
# 15              サイエンスZEROで取り上げられた科学技術や社会問題の具体例とか分かりますか？     On Task
# 16    > サイエンスZEROで取り上げられた科学技術や社会問題の具体例とか分かりますか？\n\n色...     On Task
# 17    > &gt; サイエンスZEROで取り上げられた科学技術や社会問題の具体例とか分かりますか？...     On Task
# 18                         そろそろ課題3新番組の提案に関する話し合いをしませんか？    Off Task
# 19                > そろそろ課題3新番組の提案に関する話し合いをしませんか？\nそうですね    Off Task
# 20                       学習課題から考えましょう\n何か面白い学習内容はありますか？     On Task
# 21                     ちょっとマニアックな部分になりますが、人工知能とかどうでしょう？     On Task
# 22    > ちょっとマニアックな部分になりますが、人工知能とかどうでしょう？\n\n人工知能の概要や...     On Task
# 23                                      では人工知能路線で行きましょう     On Task
# 24     番組内容が難しくなると思うので対象者は高校生から大人をターゲットに絞りたいのですがどうでしょう？     On Task
# 25    > 番組内容が難しくなると思うので対象者は高校生から大人をターゲットに絞りたいのですがどうで...     On Task
# 26                                       番組内容はどうしましょうか？     On Task
# 27                       番組内容は人工知能の歴史、現在の研究・開発事例とかにします？     On Task
# 28    > 番組内容はどうしましょうか？\n\n毎回専門家を呼び、講義形式でわたべさんが発言した人工...     On Task
# 29                                          なんか発言してください    Off Task
# ...                                                 ...         ...
# 4987               > 共有テキストの下半分のやつで出しちゃおうと思ってる\nわかりました！    Off task
# 4988                                       じゃあ提出しておきますね    Off task
# 4989                                             提出しました    Off task
# 4990                             > 提出しました\nありがとうございます！！    Off task
# 4991                              > 提出しました\nありがとうございます！    Off task
# 4992                                   共有テキスト一回消しちゃいます？    Off task
# 4993                        > 共有テキスト一回消しちゃいます？\nそうしましょう    Off task
# 4994           > 共有テキスト一回消しちゃいます？\nそうしましょう！で、課題2やりましょう！    Off task
# 4995             TinCanとは多種多様な学習活動の履歴を記録・検索・抽出するためのしすてむ     On task
# 4996                        SCORMの次世代版でビッグデータにも対応してるらしい     On task
# 4997  LMSに依存することなくあらゆる学習についての記録ができるため、さまざまな活用方法を期待する...     On task
# 4998                               スマホアプリやタブレットでの利用もできる     On task
# 4999                                    今出てきた意見全部繋げちゃう？    Off task
# 5000                                            あと位置づけか     On task
# 5001                    > 今出てきた意見全部繋げちゃう？\n今つなげようとしてます！    Off task
# 5002   > &gt; 今出てきた意見全部繋げちゃう？\n\n> 今つなげようとしてます！\nお願いします    Off task
# 5003  次世代SCORMとして発表された規格で、正式名称はExperience API（略称：xAP...     On task
# 5004  > &gt; 今出てきた意見全部繋げちゃう？\n\n> 今つなげようとしてます！\n\nあり...    Off task
# 5005  > 次世代SCORMとして発表された規格で、正式名称はExperience API（略称：x...     On task
# 5006                                    共有テキストので良いと思います     On task
# 5007                         > 共有テキストので良いと思います\n大丈夫ですか？     On task
# 5008           > 共有テキストので良いと思います\n私もそう思います、分かりやすくていいです！     On task
# 5009                                           提出お願いします    Off task
# 5010  > &gt; 共有テキストので良いと思います\n\n> 私もそう思います、分かりやすくていい...    Off task
# 5011                                         課題2提出完了です！    Off task
# 5012                          > 課題2提出完了です！\nありがとうございます！    Off task
# 5013                           > 課題2提出完了です！\nありがとうございます    Off task
# 5014                                           課題3やりますか    Off task
# 5015              > 課題3やりますか\nやりましょう、共有テキストいったん消しちゃいますね    Off task
# 5016                            「何を」の部分の選択肢が後1つくらい欲しいかな    Off task
#
#      epistemic_b          coordination_a          coordination_b  \
# 0       Off Task                     NaN                     NaN
# 1       Off Task                     NaN                     NaN
# 2       Off Task                     NaN                     NaN
# 3       Off Task  Technical coordination  Technical coordination
# 4       Off Task                     NaN  Technical coordination
# 5       No Sense                     NaN  Technical coordination
# 6       Off Task                     NaN                     NaN
# 7       Off Task                     NaN                     NaN
# 8       Off Task                     NaN                     NaN
# 9       Off Task                     NaN                     NaN
# 10      Off Task                     NaN         Time management
# 11       On Task                     NaN                     NaN
# 12      No Sense                     NaN                     NaN
# 13       On Task                     NaN                     NaN
# 14       On Task                     NaN                     NaN
# 15       On Task                     NaN                     NaN
# 16       On Task                     NaN                     NaN
# 17       On Task                     NaN                     NaN
# 18      Off Task           Task division             Proceedings
# 19      Off Task                     NaN                     NaN
# 20      Off Task                     NaN             Proceedings
# 21       On Task                     NaN                     NaN
# 22       On Task                     NaN                     NaN
# 23       On Task                     NaN                     NaN
# 24       On Task                     NaN                     NaN
# 25       On Task                     NaN                     NaN
# 26      Off Task                     NaN             Proceedings
# 27       On Task                     NaN                     NaN
# 28       On Task                     NaN                     NaN
# 29      Off Task                     NaN                     NaN
# ...          ...                     ...                     ...
# 4987    Off Task  Technical coordination                     NaN
# 4988    Off Task  Technical coordination  Technical coordination
# 4989    Off Task  Technical coordination  Technical coordination
# 4990    Off Task                     NaN                     NaN
# 4991    Off Task                     NaN                     NaN
# 4992    Off Task  Technical coordination  Technical coordination
# 4993    Off Task  Technical coordination                     NaN
# 4994    Off Task             Proceedings                     NaN
# 4995     On Task                     NaN                     NaN
# 4996     On Task                     NaN                     NaN
# 4997     On Task                     NaN                     NaN
# 4998     On Task                     NaN                     NaN
# 4999    Off Task             Proceedings                     NaN
# 5000    Off Task                     NaN                     NaN
# 5001    Off Task  Technical coordination                     NaN
# 5002    Off Task  Technical coordination                     NaN
# 5003     On Task                     NaN                     NaN
# 5004    Off Task  Technical coordination                     NaN
# 5005     On Task                     NaN                     NaN
# 5006    Off Task                     NaN                     NaN
# 5007    Off Task                     NaN                     NaN
# 5008    Off Task                     NaN                     NaN
# 5009    Off Task  Technical coordination           Task division
# 5010    Off Task  Technical coordination  Technical coordination
# 5011    Off Task  Technical coordination  Technical coordination
# 5012    Off Task                     NaN                     NaN
# 5013    Off Task                     NaN                     NaN
# 5014    Off Task             Proceedings             Proceedings
# 5015    Off Task  Technical coordination  Technical coordination
# 5016    Off Task                     NaN                     NaN
#
#                    argument_a               argument_b  \
# 0     Non-argumentative moves  Non-argumentative moves
# 1     Non-argumentative moves  Non-argumentative moves
# 2     Non-argumentative moves  Non-argumentative moves
# 3     Non-argumentative moves  Non-argumentative moves
# 4     Non-argumentative moves  Non-argumentative moves
# 5     Non-argumentative moves                      NaN
# 6     Non-argumentative moves  Non-argumentative moves
# 7     Non-argumentative moves  Non-argumentative moves
# 8     Non-argumentative moves  Non-argumentative moves
# 9     Non-argumentative moves  Non-argumentative moves
# 10    Non-argumentative moves  Non-argumentative moves
# 11    Non-argumentative moves  Non-argumentative moves
# 12                        NaN                      NaN
# 13               Simple Claim             Simple Claim
# 14               Simple Claim             Simple Claim
# 15    Non-argumentative moves  Non-argumentative moves
# 16               Simple Claim           Grounded Claim
# 17    Non-argumentative moves             Simple Claim
# 18    Non-argumentative moves  Non-argumentative moves
# 19    Non-argumentative moves  Non-argumentative moves
# 20    Non-argumentative moves  Non-argumentative moves
# 21    Non-argumentative moves             Simple Claim
# 22               Simple Claim             Simple Claim
# 23               Simple Claim             Simple Claim
# 24             Grounded Claim           Grounded Claim
# 25               Simple Claim             Simple Claim
# 26    Non-argumentative moves  Non-argumentative moves
# 27    Non-argumentative moves             Simple Claim
# 28               Simple Claim             Simple Claim
# 29    Non-argumentative moves  Non-argumentative moves
# ...                       ...                      ...
# 4987  Non-argumentative moves  Non-argumentative moves
# 4988  Non-argumentative moves  Non-argumentative moves
# 4989  Non-argumentative moves  Non-argumentative moves
# 4990  Non-argumentative moves  Non-argumentative moves
# 4991  Non-argumentative moves  Non-argumentative moves
# 4992  Non-argumentative moves  Non-argumentative moves
# 4993  Non-argumentative moves  Non-argumentative moves
# 4994  Non-argumentative moves  Non-argumentative moves
# 4995             Simple claim             Simple Claim
# 4996             Simple claim             Simple Claim
# 4997           Grounded claim             Simple Claim
# 4998             Simple claim             Simple Claim
# 4999  Non-argumentative moves  Non-argumentative moves
# 5000             Simple claim  Non-argumentative moves
# 5001  Non-argumentative moves  Non-argumentative moves
# 5002  Non-argumentative moves  Non-argumentative moves
# 5003             Simple claim             Simple Claim
# 5004  Non-argumentative moves  Non-argumentative moves
# 5005             Simple claim             Simple Claim
# 5006             Simple claim  Non-argumentative moves
# 5007  Non-argumentative moves  Non-argumentative moves
# 5008             Simple claim  Non-argumentative moves
# 5009  Non-argumentative moves  Non-argumentative moves
# 5010  Non-argumentative moves  Non-argumentative moves
# 5011  Non-argumentative moves  Non-argumentative moves
# 5012  Non-argumentative moves  Non-argumentative moves
# 5013  Non-argumentative moves  Non-argumentative moves
# 5014  Non-argumentative moves  Non-argumentative moves
# 5015  Non-argumentative moves  Non-argumentative moves
# 5016  Non-argumentative moves  Non-argumentative moves
#
#                                      social_a  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11                                Elicitation
# 12                                        NaN
# 13                            Externalization
# 14                   Quick consensus building
# 15                                Elicitation
# 16                            Externalization
# 17                   Quick consensus building
# 18                                        NaN
# 19                                        NaN
# 20                                Elicitation
# 21                                Elicitation
# 22    Integrarion-oriented consensus building
# 23                   Quick consensus building
# 24                            Externalization
# 25                   Quick consensus building
# 26                                Elicitation
# 27                                Elicitation
# 28                            Externalization
# 29                                        NaN
# ...                                       ...
# 4987                                      NaN
# 4988                                      NaN
# 4989                                      NaN
# 4990                                      NaN
# 4991                                      NaN
# 4992                                      NaN
# 4993                                      NaN
# 4994                                      NaN
# 4995                          Externalization
# 4996                          Externalization
# 4997                          Externalization
# 4998                          Externalization
# 4999                                      NaN
# 5000                          Externalization
# 5001                                      NaN
# 5002                                      NaN
# 5003                          Externalization
# 5004                                      NaN
# 5005                 Quick consensus building
# 5006                 Quick consensus building
# 5007                              Elicitation
# 5008                 Quick consensus building
# 5009                                      NaN
# 5010                                      NaN
# 5011                                      NaN
# 5012                                      NaN
# 5013                                      NaN
# 5014                                      NaN
# 5015                                      NaN
# 5016                                      NaN
#
#                                      social_b
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11                                Elicitation
# 12                                        NaN
# 13                            Externalization
# 14                   Quick consensus building
# 15                                Elicitation
# 16                            Externalization
# 17                   Quick consensus building
# 18                                        NaN
# 19                                        NaN
# 20                                        NaN
# 21                            Externalization
# 22                   Quick consensus building
# 23                   Quick consensus building
# 24                            Externalization
# 25                   Quick consensus building
# 26                                        NaN
# 27                            Externalization
# 28    Integrarion-oriented consensus building
# 29                                        NaN
# ...                                       ...
# 4987                                      NaN
# 4988                                      NaN
# 4989                                      NaN
# 4990                                      NaN
# 4991                                      NaN
# 4992                                      NaN
# 4993                                      NaN
# 4994                                      NaN
# 4995                          Externalization
# 4996                          Externalization
# 4997                          Externalization
# 4998                          Externalization
# 4999                                      NaN
# 5000                                      NaN
# 5001                                      NaN
# 5002                                      NaN
# 5003                          Externalization
# 5004                                      NaN
# 5005                 Quick consensus building
# 5006                                      NaN
# 5007                                      NaN
# 5008                                      NaN
# 5009                                      NaN
# 5010                                      NaN
# 5011                                      NaN
# 5012                                      NaN
# 5013                                      NaN
# 5014                                      NaN
# 5015                                      NaN
# 5016                                      NaN
#
# [5017 rows x 13 columns]

# %%
#　順番の整理
col_1 = [
    'say_id', 'reply_id', 'group_id', 'name', 'body', 'argument_a',
    'argument_b', 'epistemic_a', 'epistemic_b', 'social_a', 'social_b',
    'coordination_a', 'coordination_b'
]
A_W_df = A_W_df[col_1]
S_H_171116_df = S_H_171116_df[col_1]

# %%
A_W_df
# Out:
#      say_id reply_id group_id     name  \
# 0         1       \N        1     まこぴす
# 1        31       \N        1        哲
# 2        70       \N        1       仙波
# 3       119       \N        1     まこぴす
# 4       163       \N        1       仙波
# 5       194       \N        1     まこぴす
# 6       302       \N        1        哲
# 7       309       \N        1       仙波
# 8       385       \N        1     まこぴす
# 9       426       \N        1     まこぴす
# 10      500       \N        1       仙波
# 11      528       \N        1       仙波
# 12      693       \N        1     まこぴす
# 13      715       \N        1       仙波
# 14      746       \N        1     まこぴす
# 15      791       \N        1       仙波
# 16      813       \N        1     まこぴす
# 17      830      746        1        哲
# 18      831       \N        1       仙波
# 19      851      813        1        哲
# 20      888       \N        1       仙波
# 21      899       \N        1     まこぴす
# 22      916       \N        1       仙波
# 23      934      899        1        哲
# 24      964       \N        1     まこぴす
# 25      990       \N        1       仙波
# 26     1017       \N        1       \N
# 27     1031       \N        1     まこぴす
# 28     1048       \N        1       仙波
# 29     1066       \N        1        哲
# ...     ...      ...      ...      ...
# 4915   3963       \N     1004  だいきでかいと
# 4916   3982       \N     1004       星矢
# 4917   4009       \N     1004       星矢
# 4918   4017     4009     1004  だいきでかいと
# 4919   4038       \N     1004       星矢
# 4920   4086     4038     1004  だいきでかいと
# 4921   4111       \N     1004       星矢
# 4922   4134     4111     1004  だいきでかいと
# 4923   4147       \N     1004  だいきでかいと
# 4924   4160       \N     1004       星矢
# 4925   4171       \N     1004  だいきでかいと
# 4926   4196       \N     1004  だいきでかいと
# 4927   4207       \N     1004       星矢
# 4928   4219       \N     1004       星矢
# 4929   4224     4207     1004  だいきでかいと
# 4930   4245       \N     1004  だいきでかいと
# 4931   4264     4245     1004       星矢
# 4932   4303       \N     1004  だいきでかいと
# 4933   4329       \N     1004  だいきでかいと
# 4934   4372       \N     1004       星矢
# 4935   4377       \N     1004  だいきでかいと
# 4936   4392     4377     1004       星矢
# 4937   4401     4392     1004  だいきでかいと
# 4938   4453     4401     1004       星矢
# 4939   4464       \N     1004  だいきでかいと
# 4940   3805       \N     1005       モブ
# 4941   4088       \N     1005       モブ
# 4942   4505       \N     1005       モブ
# 4943   4921       \N     1005       モブ
# 4944    NaN      NaN      NaN      NaN
#
#                                                    body  \
# 0                                           よろしくお願いします！
# 1                                            よろしくお願いします
# 2                          名前なのが恥ずかしいです…\n\nよろしくお願いします！
# 3                                        早速課題やっちゃいましょう！
# 4                             やっちゃいましょう\n\nmoodleはゴミです！
# 5                                            使いにくいです(笑)
# 6                                                  同意です
# 7     以前インタラクティブアート受講していたのですが、その時に課題が不具合で出せなくなっていた時期...
# 8     学習環境として必要最低限の機能は備えていると思うが、操作性の面ではPCの最低限の知識があるこ...
# 9                                           自分の意見です！(笑)
# 10                                             ほぼほぼ同意です
# 11                                    他に何か考えてることなどありますか
# 12                                          他に意見ありますかー？
# 13                                              自分はないです
# 14                                            哲さんどうですか？
# 15                  まこびすさんがいい感じにまとめてくれたので自分はこれでいいと思います！
# 16                             １度共有テキスト全部消して現在の回答案書きます！
# 17                       > 哲さんどうですか？\n\n自分もみなさんの意見に同意です
# 18                                                 了解です
# 19                                           ありがとうございます
# 20                                    あざっす\n\nこれでいいのでは？
# 21                      こちらの回答案でよければ課題回答しちゃいますけど大丈夫ですか？
# 22                                              自分は平気です
# 23                                          よろしくお願いします！
# 24                                                完了です！
# 25                                              お疲れ様です！
# 26                                           １番乗りおめでとう！
# 27                                        ありがとうございます(笑)
# 28                                                  でた！
# 29                       お役に立てず申し訳ございません\n\nありがとうごいました！
# ...                                                 ...
# 4915               それかあえて、子供を対象者から外して、親に対するものにするものありかも。
# 4916                                  本当は怖い　～ターゲットは我が子～
# 4917                      でも使うのは子供だから子供を外すのはちょっと違ってくるよね
# 4918            > でも使うのは子供だから子供を外すのはちょっと違ってくるよね\n\n確かに。
# 4919                                まさかの一番の悩みがタイトルっていう…
# 4920                   > まさかの一番の悩みがタイトルっていう…\n\nそれ。\n\n
# 4921                                タイトル作ってみたけどこれでいいかな？
# 4922  > タイトル作ってみたけどこれでいいかな？\n\nいきましょう\n\nそれで。\n\n私めは...
# 4923                                              亭主TUー
# 4924                                 もうちょっと工夫点・特徴点ないかな？
# 4925                                 考えますか。\n\nうーん。\n\n
# 4926                                          おやこ登場\n\n
# 4927                                        モザイク・変声必至だな
# 4928                                     データ放送使えないだろうか？
# 4929                  > モザイク・変声必至だな\n\n間違いない。スモークの衝立必要。
# 4930                        使えそう。\n\n質問項目を設けるか。\n\nクイズ？
# 4931  > 使えそう。\n\n\n\n> 質問項目を設けるか。\n\n\n\n> クイズ？\n\n\...
# 4932                             クイズ正解者にはウィルスソフトプレゼントー！
# 4933                                    他にはなにかあるかな；\n\n
# 4934                                  何も出てこない\n\nネタが尽きた
# 4935                              これちなみにこの一つ提出したら良いのよね？
# 4936                > これちなみにこの一つ提出したら良いのよね？\n\n\n\nそうだよ
# 4937  > &gt; これちなみにこの一つ提出したら良いのよね？\n\n> そうだよ\n\n\n\n...
# 4938  > &gt; &gt; これちなみにこの一つ提出したら良いのよね？\n\n\n\n> &gt...
# 4939                                              おっつん。
# 4940                                       よろしくおねがいします。
# 4941                              なにか新しい教育番組の案などありませんか？
# 4942            対象者:Englishというのは外国の方が対象者ということでよいのでしょうか？
# 4943                              回答出していただいてありがとうございます。
# 4944                                                NaN
#
#                         argument_a                    argument_b epistemic_a  \
# 0          Non-argumentative moves       Non-argumentative moves    Off task
# 1          Non-argumentative moves       Non-argumentative moves    Off task
# 2          Non-argumentative moves       Non-argumentative moves    Off task
# 3          Non-argumentative moves       Non-argumentative moves    Off task
# 4                     Simple claim                  Simple Claim     On task
# 5                     Simple claim                  Simple Claim     On task
# 6                     Simple claim                  Simple Claim     On task
# 7                   Grounded claim                Grounded Claim     On task
# 8     Grounded and Qualified claim  Grounded and Qualified claim     On task
# 9          Non-argumentative moves                  Simple Claim    Off task
# 10                    Simple claim                  Simple Claim     On task
# 11         Non-argumentative moves       Non-argumentative moves     On task
# 12         Non-argumentative moves       Non-argumentative moves     On task
# 13         Non-argumentative moves                  Simple Claim     On task
# 14         Non-argumentative moves       Non-argumentative moves     On task
# 15                  Grounded claim                  Simple Claim     On task
# 16         Non-argumentative moves       Non-argumentative moves    Off task
# 17                    Simple claim                  Simple Claim     On task
# 18         Non-argumentative moves                  Simple Claim     On task
# 19         Non-argumentative moves                  Simple Claim    Off task
# 20         Non-argumentative moves                  Simple Claim    Off task
# 21         Non-argumentative moves       Non-argumentative moves    Off task
# 22         Non-argumentative moves       Non-argumentative moves    Off task
# 23         Non-argumentative moves       Non-argumentative moves    Off task
# 24         Non-argumentative moves       Non-argumentative moves    Off task
# 25         Non-argumentative moves       Non-argumentative moves    Off task
# 26         Non-argumentative moves       Non-argumentative moves    Off task
# 27         Non-argumentative moves       Non-argumentative moves    Off task
# 28         Non-argumentative moves       Non-argumentative moves    Off task
# 29         Non-argumentative moves       Non-argumentative moves    Off task
# ...                            ...                           ...         ...
# 4915                  Simple Claim                  Simple Claim     On Task
# 4916                  Simple Claim                  Simple Claim     On Task
# 4917                Grounded Claim                  Simple Claim     On Task
# 4918                  Simple Claim                  Simple Claim     On Task
# 4919                  Simple Claim       Non-argumentative moves     On Task
# 4920                  Simple Claim       Non-argumentative moves     On Task
# 4921       Non-argumentative moves       Non-argumentative moves     On Task
# 4922                Grounded Claim       Non-argumentative moves     On Task
# 4923                           NaN       Non-argumentative moves    No Sense
# 4924       Non-argumentative moves       Non-argumentative moves     On Task
# 4925       Non-argumentative moves       Non-argumentative moves    Off Task
# 4926                  Simple Claim                  Simple Claim     On Task
# 4927                  Simple Claim                  Simple Claim     On Task
# 4928                  Simple Claim                  Simple Claim     On Task
# 4929                  Simple Claim                  Simple Claim     On Task
# 4930                  Simple Claim                  Simple Claim     On Task
# 4931                  Simple Claim                  Simple Claim     On Task
# 4932                  Simple Claim                  Simple Claim     On Task
# 4933       Non-argumentative moves       Non-argumentative moves    Off Task
# 4934                  Simple Claim       Non-argumentative moves     On Task
# 4935       Non-argumentative moves       Non-argumentative moves    Off Task
# 4936       Non-argumentative moves       Non-argumentative moves    Off Task
# 4937       Non-argumentative moves       Non-argumentative moves    Off Task
# 4938       Non-argumentative moves       Non-argumentative moves    Off Task
# 4939       Non-argumentative moves       Non-argumentative moves    Off Task
# 4940       Non-argumentative moves       Non-argumentative moves    Off Task
# 4941       Non-argumentative moves       Non-argumentative moves    Off Task
# 4942       Non-argumentative moves       Non-argumentative moves     On Task
# 4943       Non-argumentative moves       Non-argumentative moves    Off Task
# 4944                           NaN                           NaN         NaN
#
#      epistemic_b                              social_a  \
# 0       Off Task                                   NaN
# 1       Off Task                                   NaN
# 2       Off Task                                   NaN
# 3       Off Task                                   NaN
# 4        On Task                       Externalization
# 5        On Task                       Externalization
# 6        On Task              Quick consensus building
# 7        On Task                       Externalization
# 8        On Task                       Externalization
# 9        On Task                                   NaN
# 10       On Task              Quick consensus building
# 11       On Task                           Elicitation
# 12       On Task                           Elicitation
# 13       On Task              Quick consensus building
# 14      Off Task                           Elicitation
# 15       On Task                       Externalization
# 16      Off Task                                   NaN
# 17       On Task              Quick consensus building
# 18       On Task              Quick consensus building
# 19       On Task                                   NaN
# 20       On Task                                   NaN
# 21      Off Task                                   NaN
# 22      Off Task                                   NaN
# 23      Off Task                                   NaN
# 24      Off Task                                   NaN
# 25      Off Task                                   NaN
# 26      Off Task                                   NaN
# 27      Off Task                                   NaN
# 28      Off Task                                   NaN
# 29      Off Task                                   NaN
# ...          ...                                   ...
# 4915     On Task                       Externalization
# 4916     On Task                                   NaN
# 4917     On Task  Conflict-oriented consensus building
# 4918     On Task              Quick consensus building
# 4919    Off Task                       Externalization
# 4920    Off Task              Quick consensus building
# 4921    Off Task                           Elicitation
# 4922    Off Task              Quick consensus building
# 4923    Off Task                                   NaN
# 4924    Off Task                           Elicitation
# 4925    Off Task                                   NaN
# 4926     On Task                       Externalization
# 4927     On Task                                   NaN
# 4928     On Task                       Externalization
# 4929     On Task              Quick consensus building
# 4930     On Task                                   NaN
# 4931     On Task              Quick consensus building
# 4932     On Task                       Externalization
# 4933    Off Task                                   NaN
# 4934    Off Task                                   NaN
# 4935    Off Task                                   NaN
# 4936    Off Task                                   NaN
# 4937    Off Task                                   NaN
# 4938    Off Task                                   NaN
# 4939    Off Task                                   NaN
# 4940    Off Task                                   NaN
# 4941    Off Task                                   NaN
# 4942     On Task                           Elicitation
# 4943    Off Task                                   NaN
# 4944         NaN                                   NaN
#
#                                      social_b          coordination_a  \
# 0                                         NaN                     NaN
# 1                                         NaN                     NaN
# 2                                         NaN                     NaN
# 3                                         NaN             Proceedings
# 4                                         NaN                     NaN
# 5                                         NaN                     NaN
# 6                    Quick consensus building                     NaN
# 7                             Externalization                     NaN
# 8                             Externalization                     NaN
# 9                             Externalization                     NaN
# 10                   Quick consensus building                     NaN
# 11                                Elicitation                     NaN
# 12                                Elicitation                     NaN
# 13                            Externalization                     NaN
# 14                                        NaN                     NaN
# 15                   Quick consensus building                     NaN
# 16                                        NaN  Technical coordination
# 17                   Quick consensus building                     NaN
# 18                   Quick consensus building                     NaN
# 19                   Quick consensus building                     NaN
# 20                   Quick consensus building                     NaN
# 21                                        NaN             Proceedings
# 22                                        NaN                     NaN
# 23                                        NaN                     NaN
# 24                                        NaN  Technical coordination
# 25                                        NaN                     NaN
# 26                                        NaN                     NaN
# 27                                        NaN                     NaN
# 28                                        NaN                     NaN
# 29                                        NaN                     NaN
# ...                                       ...                     ...
# 4915  Integrarion-oriented consensus building                     NaN
# 4916                          Externalization                     NaN
# 4917     Conflict-oriented consensus building                     NaN
# 4918                 Quick consensus building                     NaN
# 4919                                      NaN                     NaN
# 4920                                      NaN                     NaN
# 4921                                      NaN                     NaN
# 4922                                      NaN                     NaN
# 4923                                      NaN                     NaN
# 4924                                      NaN                     NaN
# 4925                                      NaN           Task division
# 4926                          Externalization                     NaN
# 4927                 Quick consensus building                     NaN
# 4928                          Externalization                     NaN
# 4929                 Quick consensus building                     NaN
# 4930  Integrarion-oriented consensus building                     NaN
# 4931                 Quick consensus building                     NaN
# 4932                          Externalization                     NaN
# 4933                                      NaN             Proceedings
# 4934                                      NaN                     NaN
# 4935                                      NaN           Task division
# 4936                                      NaN           Task division
# 4937                                      NaN         Time management
# 4938                                      NaN                     NaN
# 4939                                      NaN                     NaN
# 4940                                      NaN                     NaN
# 4941                                      NaN             Proceedings
# 4942                              Elicitation                     NaN
# 4943                                      NaN                     NaN
# 4944                                      NaN                     NaN
#
#               coordination_b
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                Proceedings
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14               Proceedings
# 15                       NaN
# 16    Technical coordination
# 17                       NaN
# 18                       NaN
# 19                       NaN
# 20                       NaN
# 21    Technical coordination
# 22                       NaN
# 23                       NaN
# 24    Technical coordination
# 25                       NaN
# 26                       NaN
# 27                       NaN
# 28                       NaN
# 29                       NaN
# ...                      ...
# 4915                     NaN
# 4916                     NaN
# 4917                     NaN
# 4918                     NaN
# 4919                     NaN
# 4920                     NaN
# 4921                     NaN
# 4922                     NaN
# 4923                     NaN
# 4924             Proceedings
# 4925                     NaN
# 4926                     NaN
# 4927                     NaN
# 4928                     NaN
# 4929                     NaN
# 4930                     NaN
# 4931                     NaN
# 4932                     NaN
# 4933                     NaN
# 4934                     NaN
# 4935  Technical coordination
# 4936                     NaN
# 4937                     NaN
# 4938                     NaN
# 4939                     NaN
# 4940                     NaN
# 4941             Proceedings
# 4942                     NaN
# 4943  Technical coordination
# 4944                     NaN
#
# [4945 rows x 13 columns]

# %%
S_H_171116_df
# Out:
#      say_id reply_id group_id    name  \
# 0      1593       \N        1  世界のわたべ
# 1      1598       \N        1    ざきさん
# 2      1606       \N        1       あ
# 3      1659       \N        1    ざきさん
# 4      1683       \N        1       あ
# 5      1692       \N        1  世界のわたべ
# 6      1704       \N        1    ざきさん
# 7      1794       \N        1    ざきさん
# 8      1821       \N        1       あ
# 9      1914       \N        1  世界のわたべ
# 10     1926       \N        1    ざきさん
# 11     2102       \N        1  世界のわたべ
# 12     2103       \N        1  世界のわたべ
# 13     2157     2103        1    ざきさん
# 14     2172     2157        1  世界のわたべ
# 15     2274       \N        1  世界のわたべ
# 16     2455     2274        1       あ
# 17     2482     2455        1  世界のわたべ
# 18     2500       \N        1    ざきさん
# 19     2509     2500        1  世界のわたべ
# 20     2552       \N        1    ざきさん
# 21     2653       \N        1  世界のわたべ
# 22     2687     2653        1    ざきさん
# 23     2740       \N        1  世界のわたべ
# 24     2772       \N        1  世界のわたべ
# 25     2792     2772        1    ざきさん
# 26     2809       \N        1  世界のわたべ
# 27     2900       \N        1  世界のわたべ
# 28     2947     2809        1    ざきさん
# 29     2959       \N        1    ざきさん
# ...     ...      ...      ...     ...
# 4987   6241     6224    10001     まささ
# 4988   6243       \N    10001    オノヅカ
# 4989   6254       \N    10001    オノヅカ
# 4990   6257     6254    10001     まささ
# 4991   6264     6254    10001     みずき
# 4992   6266       \N    10001    オノヅカ
# 4993   6278     6266    10001     まささ
# 4994   6280     6266    10001     みずき
# 4995   6288       \N    10001    オノヅカ
# 4996   6326       \N    10001    オノヅカ
# 4997   6347       \N    10001     みずき
# 4998   6363       \N    10001     まささ
# 4999   6388       \N    10001    オノヅカ
# 5000   6397       \N    10001    オノヅカ
# 5001   6404     6388    10001     みずき
# 5002   6410     6404    10001    オノヅカ
# 5003   6415       \N    10001     まささ
# 5004   6419     6404    10001     まささ
# 5005   6435     6415    10001     みずき
# 5006   6436       \N    10001    オノヅカ
# 5007   6441     6436    10001     みずき
# 5008   6443     6436    10001     まささ
# 5009   6449       \N    10001    オノヅカ
# 5010   6451     6443    10001     みずき
# 5011   6459       \N    10001     みずき
# 5012   6463     6459    10001     まささ
# 5013   6467     6459    10001    オノヅカ
# 5014   6477       \N    10001    オノヅカ
# 5015   6491     6477    10001     まささ
# 5016   6521       \N    10001    オノヅカ
#
#                                                    body  \
# 0                                           よろしくお願いします。
# 1                                                よろしくです
# 2                                                よろしくです
# 3                                    みなさんファイルをアップしましたか？
# 4                                             今アップしました！
# 5                                             今アップしました！
# 6                                                名前バレｗｗ
# 7                                              質問特にないです
# 8                                             同じく特に無いです
# 9                                                 いますよー
# 10                                        宿題の批評、終わりました。
# 11    「いのちの創造」とは、生命に対する言葉ですか？もしくは絵とか作品に命を吹き込むという意味の言...
# 12    「いのちの創造」とは、生命に対する言葉ですか？もしくは絵とか作品に命を吹き込むという意味の言...
# 13    > 「いのちの創造」とは、生命に対する言葉ですか？もしくは絵とか作品に命を吹き込むという意味...
# 14    > &gt; 「いのちの創造」とは、生命に対する言葉ですか？もしくは絵とか作品に命を吹き込む...
# 15              サイエンスZEROで取り上げられた科学技術や社会問題の具体例とか分かりますか？
# 16    > サイエンスZEROで取り上げられた科学技術や社会問題の具体例とか分かりますか？\n\n色...
# 17    > &gt; サイエンスZEROで取り上げられた科学技術や社会問題の具体例とか分かりますか？...
# 18                         そろそろ課題3新番組の提案に関する話し合いをしませんか？
# 19                > そろそろ課題3新番組の提案に関する話し合いをしませんか？\nそうですね
# 20                       学習課題から考えましょう\n何か面白い学習内容はありますか？
# 21                     ちょっとマニアックな部分になりますが、人工知能とかどうでしょう？
# 22    > ちょっとマニアックな部分になりますが、人工知能とかどうでしょう？\n\n人工知能の概要や...
# 23                                      では人工知能路線で行きましょう
# 24     番組内容が難しくなると思うので対象者は高校生から大人をターゲットに絞りたいのですがどうでしょう？
# 25    > 番組内容が難しくなると思うので対象者は高校生から大人をターゲットに絞りたいのですがどうで...
# 26                                       番組内容はどうしましょうか？
# 27                       番組内容は人工知能の歴史、現在の研究・開発事例とかにします？
# 28    > 番組内容はどうしましょうか？\n\n毎回専門家を呼び、講義形式でわたべさんが発言した人工...
# 29                                          なんか発言してください
# ...                                                 ...
# 4987               > 共有テキストの下半分のやつで出しちゃおうと思ってる\nわかりました！
# 4988                                       じゃあ提出しておきますね
# 4989                                             提出しました
# 4990                             > 提出しました\nありがとうございます！！
# 4991                              > 提出しました\nありがとうございます！
# 4992                                   共有テキスト一回消しちゃいます？
# 4993                        > 共有テキスト一回消しちゃいます？\nそうしましょう
# 4994           > 共有テキスト一回消しちゃいます？\nそうしましょう！で、課題2やりましょう！
# 4995             TinCanとは多種多様な学習活動の履歴を記録・検索・抽出するためのしすてむ
# 4996                        SCORMの次世代版でビッグデータにも対応してるらしい
# 4997  LMSに依存することなくあらゆる学習についての記録ができるため、さまざまな活用方法を期待する...
# 4998                               スマホアプリやタブレットでの利用もできる
# 4999                                    今出てきた意見全部繋げちゃう？
# 5000                                            あと位置づけか
# 5001                    > 今出てきた意見全部繋げちゃう？\n今つなげようとしてます！
# 5002   > &gt; 今出てきた意見全部繋げちゃう？\n\n> 今つなげようとしてます！\nお願いします
# 5003  次世代SCORMとして発表された規格で、正式名称はExperience API（略称：xAP...
# 5004  > &gt; 今出てきた意見全部繋げちゃう？\n\n> 今つなげようとしてます！\n\nあり...
# 5005  > 次世代SCORMとして発表された規格で、正式名称はExperience API（略称：x...
# 5006                                    共有テキストので良いと思います
# 5007                         > 共有テキストので良いと思います\n大丈夫ですか？
# 5008           > 共有テキストので良いと思います\n私もそう思います、分かりやすくていいです！
# 5009                                           提出お願いします
# 5010  > &gt; 共有テキストので良いと思います\n\n> 私もそう思います、分かりやすくていい...
# 5011                                         課題2提出完了です！
# 5012                          > 課題2提出完了です！\nありがとうございます！
# 5013                           > 課題2提出完了です！\nありがとうございます
# 5014                                           課題3やりますか
# 5015              > 課題3やりますか\nやりましょう、共有テキストいったん消しちゃいますね
# 5016                            「何を」の部分の選択肢が後1つくらい欲しいかな
#
#                    argument_a               argument_b epistemic_a  \
# 0     Non-argumentative moves  Non-argumentative moves    Off Task
# 1     Non-argumentative moves  Non-argumentative moves    Off Task
# 2     Non-argumentative moves  Non-argumentative moves    Off Task
# 3     Non-argumentative moves  Non-argumentative moves    Off Task
# 4     Non-argumentative moves  Non-argumentative moves    Off Task
# 5     Non-argumentative moves                      NaN    Off Task
# 6     Non-argumentative moves  Non-argumentative moves    Off Task
# 7     Non-argumentative moves  Non-argumentative moves    Off Task
# 8     Non-argumentative moves  Non-argumentative moves    Off Task
# 9     Non-argumentative moves  Non-argumentative moves    Off Task
# 10    Non-argumentative moves  Non-argumentative moves    Off Task
# 11    Non-argumentative moves  Non-argumentative moves     On Task
# 12                        NaN                      NaN    No Sense
# 13               Simple Claim             Simple Claim     On Task
# 14               Simple Claim             Simple Claim     On Task
# 15    Non-argumentative moves  Non-argumentative moves     On Task
# 16               Simple Claim           Grounded Claim     On Task
# 17    Non-argumentative moves             Simple Claim     On Task
# 18    Non-argumentative moves  Non-argumentative moves    Off Task
# 19    Non-argumentative moves  Non-argumentative moves    Off Task
# 20    Non-argumentative moves  Non-argumentative moves     On Task
# 21    Non-argumentative moves             Simple Claim     On Task
# 22               Simple Claim             Simple Claim     On Task
# 23               Simple Claim             Simple Claim     On Task
# 24             Grounded Claim           Grounded Claim     On Task
# 25               Simple Claim             Simple Claim     On Task
# 26    Non-argumentative moves  Non-argumentative moves     On Task
# 27    Non-argumentative moves             Simple Claim     On Task
# 28               Simple Claim             Simple Claim     On Task
# 29    Non-argumentative moves  Non-argumentative moves    Off Task
# ...                       ...                      ...         ...
# 4987  Non-argumentative moves  Non-argumentative moves    Off task
# 4988  Non-argumentative moves  Non-argumentative moves    Off task
# 4989  Non-argumentative moves  Non-argumentative moves    Off task
# 4990  Non-argumentative moves  Non-argumentative moves    Off task
# 4991  Non-argumentative moves  Non-argumentative moves    Off task
# 4992  Non-argumentative moves  Non-argumentative moves    Off task
# 4993  Non-argumentative moves  Non-argumentative moves    Off task
# 4994  Non-argumentative moves  Non-argumentative moves    Off task
# 4995             Simple claim             Simple Claim     On task
# 4996             Simple claim             Simple Claim     On task
# 4997           Grounded claim             Simple Claim     On task
# 4998             Simple claim             Simple Claim     On task
# 4999  Non-argumentative moves  Non-argumentative moves    Off task
# 5000             Simple claim  Non-argumentative moves     On task
# 5001  Non-argumentative moves  Non-argumentative moves    Off task
# 5002  Non-argumentative moves  Non-argumentative moves    Off task
# 5003             Simple claim             Simple Claim     On task
# 5004  Non-argumentative moves  Non-argumentative moves    Off task
# 5005             Simple claim             Simple Claim     On task
# 5006             Simple claim  Non-argumentative moves     On task
# 5007  Non-argumentative moves  Non-argumentative moves     On task
# 5008             Simple claim  Non-argumentative moves     On task
# 5009  Non-argumentative moves  Non-argumentative moves    Off task
# 5010  Non-argumentative moves  Non-argumentative moves    Off task
# 5011  Non-argumentative moves  Non-argumentative moves    Off task
# 5012  Non-argumentative moves  Non-argumentative moves    Off task
# 5013  Non-argumentative moves  Non-argumentative moves    Off task
# 5014  Non-argumentative moves  Non-argumentative moves    Off task
# 5015  Non-argumentative moves  Non-argumentative moves    Off task
# 5016  Non-argumentative moves  Non-argumentative moves    Off task
#
#      epistemic_b                                 social_a  \
# 0       Off Task                                      NaN
# 1       Off Task                                      NaN
# 2       Off Task                                      NaN
# 3       Off Task                                      NaN
# 4       Off Task                                      NaN
# 5       No Sense                                      NaN
# 6       Off Task                                      NaN
# 7       Off Task                                      NaN
# 8       Off Task                                      NaN
# 9       Off Task                                      NaN
# 10      Off Task                                      NaN
# 11       On Task                              Elicitation
# 12      No Sense                                      NaN
# 13       On Task                          Externalization
# 14       On Task                 Quick consensus building
# 15       On Task                              Elicitation
# 16       On Task                          Externalization
# 17       On Task                 Quick consensus building
# 18      Off Task                                      NaN
# 19      Off Task                                      NaN
# 20      Off Task                              Elicitation
# 21       On Task                              Elicitation
# 22       On Task  Integrarion-oriented consensus building
# 23       On Task                 Quick consensus building
# 24       On Task                          Externalization
# 25       On Task                 Quick consensus building
# 26      Off Task                              Elicitation
# 27       On Task                              Elicitation
# 28       On Task                          Externalization
# 29      Off Task                                      NaN
# ...          ...                                      ...
# 4987    Off Task                                      NaN
# 4988    Off Task                                      NaN
# 4989    Off Task                                      NaN
# 4990    Off Task                                      NaN
# 4991    Off Task                                      NaN
# 4992    Off Task                                      NaN
# 4993    Off Task                                      NaN
# 4994    Off Task                                      NaN
# 4995     On Task                          Externalization
# 4996     On Task                          Externalization
# 4997     On Task                          Externalization
# 4998     On Task                          Externalization
# 4999    Off Task                                      NaN
# 5000    Off Task                          Externalization
# 5001    Off Task                                      NaN
# 5002    Off Task                                      NaN
# 5003     On Task                          Externalization
# 5004    Off Task                                      NaN
# 5005     On Task                 Quick consensus building
# 5006    Off Task                 Quick consensus building
# 5007    Off Task                              Elicitation
# 5008    Off Task                 Quick consensus building
# 5009    Off Task                                      NaN
# 5010    Off Task                                      NaN
# 5011    Off Task                                      NaN
# 5012    Off Task                                      NaN
# 5013    Off Task                                      NaN
# 5014    Off Task                                      NaN
# 5015    Off Task                                      NaN
# 5016    Off Task                                      NaN
#
#                                      social_b          coordination_a  \
# 0                                         NaN                     NaN
# 1                                         NaN                     NaN
# 2                                         NaN                     NaN
# 3                                         NaN  Technical coordination
# 4                                         NaN                     NaN
# 5                                         NaN                     NaN
# 6                                         NaN                     NaN
# 7                                         NaN                     NaN
# 8                                         NaN                     NaN
# 9                                         NaN                     NaN
# 10                                        NaN                     NaN
# 11                                Elicitation                     NaN
# 12                                        NaN                     NaN
# 13                            Externalization                     NaN
# 14                   Quick consensus building                     NaN
# 15                                Elicitation                     NaN
# 16                            Externalization                     NaN
# 17                   Quick consensus building                     NaN
# 18                                        NaN           Task division
# 19                                        NaN                     NaN
# 20                                        NaN                     NaN
# 21                            Externalization                     NaN
# 22                   Quick consensus building                     NaN
# 23                   Quick consensus building                     NaN
# 24                            Externalization                     NaN
# 25                   Quick consensus building                     NaN
# 26                                        NaN                     NaN
# 27                            Externalization                     NaN
# 28    Integrarion-oriented consensus building                     NaN
# 29                                        NaN                     NaN
# ...                                       ...                     ...
# 4987                                      NaN  Technical coordination
# 4988                                      NaN  Technical coordination
# 4989                                      NaN  Technical coordination
# 4990                                      NaN                     NaN
# 4991                                      NaN                     NaN
# 4992                                      NaN  Technical coordination
# 4993                                      NaN  Technical coordination
# 4994                                      NaN             Proceedings
# 4995                          Externalization                     NaN
# 4996                          Externalization                     NaN
# 4997                          Externalization                     NaN
# 4998                          Externalization                     NaN
# 4999                                      NaN             Proceedings
# 5000                                      NaN                     NaN
# 5001                                      NaN  Technical coordination
# 5002                                      NaN  Technical coordination
# 5003                          Externalization                     NaN
# 5004                                      NaN  Technical coordination
# 5005                 Quick consensus building                     NaN
# 5006                                      NaN                     NaN
# 5007                                      NaN                     NaN
# 5008                                      NaN                     NaN
# 5009                                      NaN  Technical coordination
# 5010                                      NaN  Technical coordination
# 5011                                      NaN  Technical coordination
# 5012                                      NaN                     NaN
# 5013                                      NaN                     NaN
# 5014                                      NaN             Proceedings
# 5015                                      NaN  Technical coordination
# 5016                                      NaN                     NaN
#
#               coordination_b
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3     Technical coordination
# 4     Technical coordination
# 5     Technical coordination
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10           Time management
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18               Proceedings
# 19                       NaN
# 20               Proceedings
# 21                       NaN
# 22                       NaN
# 23                       NaN
# 24                       NaN
# 25                       NaN
# 26               Proceedings
# 27                       NaN
# 28                       NaN
# 29                       NaN
# ...                      ...
# 4987                     NaN
# 4988  Technical coordination
# 4989  Technical coordination
# 4990                     NaN
# 4991                     NaN
# 4992  Technical coordination
# 4993                     NaN
# 4994                     NaN
# 4995                     NaN
# 4996                     NaN
# 4997                     NaN
# 4998                     NaN
# 4999                     NaN
# 5000                     NaN
# 5001                     NaN
# 5002                     NaN
# 5003                     NaN
# 5004                     NaN
# 5005                     NaN
# 5006                     NaN
# 5007                     NaN
# 5008                     NaN
# 5009           Task division
# 5010  Technical coordination
# 5011  Technical coordination
# 5012                     NaN
# 5013                     NaN
# 5014             Proceedings
# 5015  Technical coordination
# 5016                     NaN
#
# [5017 rows x 13 columns]

# %% [markdown]
# ## A_WとS_Hの結合

# %%
All_df = pd.concat([A_W_df, S_H_171116_df], ignore_index=True)
All_df
# Out:
#      say_id reply_id group_id  name  \
# 0         1       \N        1  まこぴす
# 1        31       \N        1     哲
# 2        70       \N        1    仙波
# 3       119       \N        1  まこぴす
# 4       163       \N        1    仙波
# 5       194       \N        1  まこぴす
# 6       302       \N        1     哲
# 7       309       \N        1    仙波
# 8       385       \N        1  まこぴす
# 9       426       \N        1  まこぴす
# 10      500       \N        1    仙波
# 11      528       \N        1    仙波
# 12      693       \N        1  まこぴす
# 13      715       \N        1    仙波
# 14      746       \N        1  まこぴす
# 15      791       \N        1    仙波
# 16      813       \N        1  まこぴす
# 17      830      746        1     哲
# 18      831       \N        1    仙波
# 19      851      813        1     哲
# 20      888       \N        1    仙波
# 21      899       \N        1  まこぴす
# 22      916       \N        1    仙波
# 23      934      899        1     哲
# 24      964       \N        1  まこぴす
# 25      990       \N        1    仙波
# 26     1017       \N        1    \N
# 27     1031       \N        1  まこぴす
# 28     1048       \N        1    仙波
# 29     1066       \N        1     哲
# ...     ...      ...      ...   ...
# 9932   6241     6224    10001   まささ
# 9933   6243       \N    10001  オノヅカ
# 9934   6254       \N    10001  オノヅカ
# 9935   6257     6254    10001   まささ
# 9936   6264     6254    10001   みずき
# 9937   6266       \N    10001  オノヅカ
# 9938   6278     6266    10001   まささ
# 9939   6280     6266    10001   みずき
# 9940   6288       \N    10001  オノヅカ
# 9941   6326       \N    10001  オノヅカ
# 9942   6347       \N    10001   みずき
# 9943   6363       \N    10001   まささ
# 9944   6388       \N    10001  オノヅカ
# 9945   6397       \N    10001  オノヅカ
# 9946   6404     6388    10001   みずき
# 9947   6410     6404    10001  オノヅカ
# 9948   6415       \N    10001   まささ
# 9949   6419     6404    10001   まささ
# 9950   6435     6415    10001   みずき
# 9951   6436       \N    10001  オノヅカ
# 9952   6441     6436    10001   みずき
# 9953   6443     6436    10001   まささ
# 9954   6449       \N    10001  オノヅカ
# 9955   6451     6443    10001   みずき
# 9956   6459       \N    10001   みずき
# 9957   6463     6459    10001   まささ
# 9958   6467     6459    10001  オノヅカ
# 9959   6477       \N    10001  オノヅカ
# 9960   6491     6477    10001   まささ
# 9961   6521       \N    10001  オノヅカ
#
#                                                    body  \
# 0                                           よろしくお願いします！
# 1                                            よろしくお願いします
# 2                          名前なのが恥ずかしいです…\n\nよろしくお願いします！
# 3                                        早速課題やっちゃいましょう！
# 4                             やっちゃいましょう\n\nmoodleはゴミです！
# 5                                            使いにくいです(笑)
# 6                                                  同意です
# 7     以前インタラクティブアート受講していたのですが、その時に課題が不具合で出せなくなっていた時期...
# 8     学習環境として必要最低限の機能は備えていると思うが、操作性の面ではPCの最低限の知識があるこ...
# 9                                           自分の意見です！(笑)
# 10                                             ほぼほぼ同意です
# 11                                    他に何か考えてることなどありますか
# 12                                          他に意見ありますかー？
# 13                                              自分はないです
# 14                                            哲さんどうですか？
# 15                  まこびすさんがいい感じにまとめてくれたので自分はこれでいいと思います！
# 16                             １度共有テキスト全部消して現在の回答案書きます！
# 17                       > 哲さんどうですか？\n\n自分もみなさんの意見に同意です
# 18                                                 了解です
# 19                                           ありがとうございます
# 20                                    あざっす\n\nこれでいいのでは？
# 21                      こちらの回答案でよければ課題回答しちゃいますけど大丈夫ですか？
# 22                                              自分は平気です
# 23                                          よろしくお願いします！
# 24                                                完了です！
# 25                                              お疲れ様です！
# 26                                           １番乗りおめでとう！
# 27                                        ありがとうございます(笑)
# 28                                                  でた！
# 29                       お役に立てず申し訳ございません\n\nありがとうごいました！
# ...                                                 ...
# 9932               > 共有テキストの下半分のやつで出しちゃおうと思ってる\nわかりました！
# 9933                                       じゃあ提出しておきますね
# 9934                                             提出しました
# 9935                             > 提出しました\nありがとうございます！！
# 9936                              > 提出しました\nありがとうございます！
# 9937                                   共有テキスト一回消しちゃいます？
# 9938                        > 共有テキスト一回消しちゃいます？\nそうしましょう
# 9939           > 共有テキスト一回消しちゃいます？\nそうしましょう！で、課題2やりましょう！
# 9940             TinCanとは多種多様な学習活動の履歴を記録・検索・抽出するためのしすてむ
# 9941                        SCORMの次世代版でビッグデータにも対応してるらしい
# 9942  LMSに依存することなくあらゆる学習についての記録ができるため、さまざまな活用方法を期待する...
# 9943                               スマホアプリやタブレットでの利用もできる
# 9944                                    今出てきた意見全部繋げちゃう？
# 9945                                            あと位置づけか
# 9946                    > 今出てきた意見全部繋げちゃう？\n今つなげようとしてます！
# 9947   > &gt; 今出てきた意見全部繋げちゃう？\n\n> 今つなげようとしてます！\nお願いします
# 9948  次世代SCORMとして発表された規格で、正式名称はExperience API（略称：xAP...
# 9949  > &gt; 今出てきた意見全部繋げちゃう？\n\n> 今つなげようとしてます！\n\nあり...
# 9950  > 次世代SCORMとして発表された規格で、正式名称はExperience API（略称：x...
# 9951                                    共有テキストので良いと思います
# 9952                         > 共有テキストので良いと思います\n大丈夫ですか？
# 9953           > 共有テキストので良いと思います\n私もそう思います、分かりやすくていいです！
# 9954                                           提出お願いします
# 9955  > &gt; 共有テキストので良いと思います\n\n> 私もそう思います、分かりやすくていい...
# 9956                                         課題2提出完了です！
# 9957                          > 課題2提出完了です！\nありがとうございます！
# 9958                           > 課題2提出完了です！\nありがとうございます
# 9959                                           課題3やりますか
# 9960              > 課題3やりますか\nやりましょう、共有テキストいったん消しちゃいますね
# 9961                            「何を」の部分の選択肢が後1つくらい欲しいかな
#
#                         argument_a                    argument_b epistemic_a  \
# 0          Non-argumentative moves       Non-argumentative moves    Off task
# 1          Non-argumentative moves       Non-argumentative moves    Off task
# 2          Non-argumentative moves       Non-argumentative moves    Off task
# 3          Non-argumentative moves       Non-argumentative moves    Off task
# 4                     Simple claim                  Simple Claim     On task
# 5                     Simple claim                  Simple Claim     On task
# 6                     Simple claim                  Simple Claim     On task
# 7                   Grounded claim                Grounded Claim     On task
# 8     Grounded and Qualified claim  Grounded and Qualified claim     On task
# 9          Non-argumentative moves                  Simple Claim    Off task
# 10                    Simple claim                  Simple Claim     On task
# 11         Non-argumentative moves       Non-argumentative moves     On task
# 12         Non-argumentative moves       Non-argumentative moves     On task
# 13         Non-argumentative moves                  Simple Claim     On task
# 14         Non-argumentative moves       Non-argumentative moves     On task
# 15                  Grounded claim                  Simple Claim     On task
# 16         Non-argumentative moves       Non-argumentative moves    Off task
# 17                    Simple claim                  Simple Claim     On task
# 18         Non-argumentative moves                  Simple Claim     On task
# 19         Non-argumentative moves                  Simple Claim    Off task
# 20         Non-argumentative moves                  Simple Claim    Off task
# 21         Non-argumentative moves       Non-argumentative moves    Off task
# 22         Non-argumentative moves       Non-argumentative moves    Off task
# 23         Non-argumentative moves       Non-argumentative moves    Off task
# 24         Non-argumentative moves       Non-argumentative moves    Off task
# 25         Non-argumentative moves       Non-argumentative moves    Off task
# 26         Non-argumentative moves       Non-argumentative moves    Off task
# 27         Non-argumentative moves       Non-argumentative moves    Off task
# 28         Non-argumentative moves       Non-argumentative moves    Off task
# 29         Non-argumentative moves       Non-argumentative moves    Off task
# ...                            ...                           ...         ...
# 9932       Non-argumentative moves       Non-argumentative moves    Off task
# 9933       Non-argumentative moves       Non-argumentative moves    Off task
# 9934       Non-argumentative moves       Non-argumentative moves    Off task
# 9935       Non-argumentative moves       Non-argumentative moves    Off task
# 9936       Non-argumentative moves       Non-argumentative moves    Off task
# 9937       Non-argumentative moves       Non-argumentative moves    Off task
# 9938       Non-argumentative moves       Non-argumentative moves    Off task
# 9939       Non-argumentative moves       Non-argumentative moves    Off task
# 9940                  Simple claim                  Simple Claim     On task
# 9941                  Simple claim                  Simple Claim     On task
# 9942                Grounded claim                  Simple Claim     On task
# 9943                  Simple claim                  Simple Claim     On task
# 9944       Non-argumentative moves       Non-argumentative moves    Off task
# 9945                  Simple claim       Non-argumentative moves     On task
# 9946       Non-argumentative moves       Non-argumentative moves    Off task
# 9947       Non-argumentative moves       Non-argumentative moves    Off task
# 9948                  Simple claim                  Simple Claim     On task
# 9949       Non-argumentative moves       Non-argumentative moves    Off task
# 9950                  Simple claim                  Simple Claim     On task
# 9951                  Simple claim       Non-argumentative moves     On task
# 9952       Non-argumentative moves       Non-argumentative moves     On task
# 9953                  Simple claim       Non-argumentative moves     On task
# 9954       Non-argumentative moves       Non-argumentative moves    Off task
# 9955       Non-argumentative moves       Non-argumentative moves    Off task
# 9956       Non-argumentative moves       Non-argumentative moves    Off task
# 9957       Non-argumentative moves       Non-argumentative moves    Off task
# 9958       Non-argumentative moves       Non-argumentative moves    Off task
# 9959       Non-argumentative moves       Non-argumentative moves    Off task
# 9960       Non-argumentative moves       Non-argumentative moves    Off task
# 9961       Non-argumentative moves       Non-argumentative moves    Off task
#
#      epistemic_b                  social_a                  social_b  \
# 0       Off Task                       NaN                       NaN
# 1       Off Task                       NaN                       NaN
# 2       Off Task                       NaN                       NaN
# 3       Off Task                       NaN                       NaN
# 4        On Task           Externalization                       NaN
# 5        On Task           Externalization                       NaN
# 6        On Task  Quick consensus building  Quick consensus building
# 7        On Task           Externalization           Externalization
# 8        On Task           Externalization           Externalization
# 9        On Task                       NaN           Externalization
# 10       On Task  Quick consensus building  Quick consensus building
# 11       On Task               Elicitation               Elicitation
# 12       On Task               Elicitation               Elicitation
# 13       On Task  Quick consensus building           Externalization
# 14      Off Task               Elicitation                       NaN
# 15       On Task           Externalization  Quick consensus building
# 16      Off Task                       NaN                       NaN
# 17       On Task  Quick consensus building  Quick consensus building
# 18       On Task  Quick consensus building  Quick consensus building
# 19       On Task                       NaN  Quick consensus building
# 20       On Task                       NaN  Quick consensus building
# 21      Off Task                       NaN                       NaN
# 22      Off Task                       NaN                       NaN
# 23      Off Task                       NaN                       NaN
# 24      Off Task                       NaN                       NaN
# 25      Off Task                       NaN                       NaN
# 26      Off Task                       NaN                       NaN
# 27      Off Task                       NaN                       NaN
# 28      Off Task                       NaN                       NaN
# 29      Off Task                       NaN                       NaN
# ...          ...                       ...                       ...
# 9932    Off Task                       NaN                       NaN
# 9933    Off Task                       NaN                       NaN
# 9934    Off Task                       NaN                       NaN
# 9935    Off Task                       NaN                       NaN
# 9936    Off Task                       NaN                       NaN
# 9937    Off Task                       NaN                       NaN
# 9938    Off Task                       NaN                       NaN
# 9939    Off Task                       NaN                       NaN
# 9940     On Task           Externalization           Externalization
# 9941     On Task           Externalization           Externalization
# 9942     On Task           Externalization           Externalization
# 9943     On Task           Externalization           Externalization
# 9944    Off Task                       NaN                       NaN
# 9945    Off Task           Externalization                       NaN
# 9946    Off Task                       NaN                       NaN
# 9947    Off Task                       NaN                       NaN
# 9948     On Task           Externalization           Externalization
# 9949    Off Task                       NaN                       NaN
# 9950     On Task  Quick consensus building  Quick consensus building
# 9951    Off Task  Quick consensus building                       NaN
# 9952    Off Task               Elicitation                       NaN
# 9953    Off Task  Quick consensus building                       NaN
# 9954    Off Task                       NaN                       NaN
# 9955    Off Task                       NaN                       NaN
# 9956    Off Task                       NaN                       NaN
# 9957    Off Task                       NaN                       NaN
# 9958    Off Task                       NaN                       NaN
# 9959    Off Task                       NaN                       NaN
# 9960    Off Task                       NaN                       NaN
# 9961    Off Task                       NaN                       NaN
#
#               coordination_a          coordination_b
# 0                        NaN                     NaN
# 1                        NaN                     NaN
# 2                        NaN                     NaN
# 3                Proceedings             Proceedings
# 4                        NaN                     NaN
# 5                        NaN                     NaN
# 6                        NaN                     NaN
# 7                        NaN                     NaN
# 8                        NaN                     NaN
# 9                        NaN                     NaN
# 10                       NaN                     NaN
# 11                       NaN                     NaN
# 12                       NaN                     NaN
# 13                       NaN                     NaN
# 14                       NaN             Proceedings
# 15                       NaN                     NaN
# 16    Technical coordination  Technical coordination
# 17                       NaN                     NaN
# 18                       NaN                     NaN
# 19                       NaN                     NaN
# 20                       NaN                     NaN
# 21               Proceedings  Technical coordination
# 22                       NaN                     NaN
# 23                       NaN                     NaN
# 24    Technical coordination  Technical coordination
# 25                       NaN                     NaN
# 26                       NaN                     NaN
# 27                       NaN                     NaN
# 28                       NaN                     NaN
# 29                       NaN                     NaN
# ...                      ...                     ...
# 9932  Technical coordination                     NaN
# 9933  Technical coordination  Technical coordination
# 9934  Technical coordination  Technical coordination
# 9935                     NaN                     NaN
# 9936                     NaN                     NaN
# 9937  Technical coordination  Technical coordination
# 9938  Technical coordination                     NaN
# 9939             Proceedings                     NaN
# 9940                     NaN                     NaN
# 9941                     NaN                     NaN
# 9942                     NaN                     NaN
# 9943                     NaN                     NaN
# 9944             Proceedings                     NaN
# 9945                     NaN                     NaN
# 9946  Technical coordination                     NaN
# 9947  Technical coordination                     NaN
# 9948                     NaN                     NaN
# 9949  Technical coordination                     NaN
# 9950                     NaN                     NaN
# 9951                     NaN                     NaN
# 9952                     NaN                     NaN
# 9953                     NaN                     NaN
# 9954  Technical coordination           Task division
# 9955  Technical coordination  Technical coordination
# 9956  Technical coordination  Technical coordination
# 9957                     NaN                     NaN
# 9958                     NaN                     NaN
# 9959             Proceedings             Proceedings
# 9960  Technical coordination  Technical coordination
# 9961                     NaN                     NaN
#
# [9962 rows x 13 columns]

# %% [markdown]
# # ラベル列のNaNを取り除いて、小文字に置換する

# %%
col_p = [
    'argument_a', 'argument_b', 'epistemic_a', 'epistemic_b', 'social_a',
    'social_b', 'coordination_a', 'coordination_b'
]

All_df['social_b'] = All_df['social_b'].replace(2723, 'blank')

All_df = All_df.fillna('blank')

for c in col_p:
    All_df[c] = All_df[c].str.lower()
All_df
# Out:
#      say_id reply_id group_id  name  \
# 0         1       \N        1  まこぴす
# 1        31       \N        1     哲
# 2        70       \N        1    仙波
# 3       119       \N        1  まこぴす
# 4       163       \N        1    仙波
# 5       194       \N        1  まこぴす
# 6       302       \N        1     哲
# 7       309       \N        1    仙波
# 8       385       \N        1  まこぴす
# 9       426       \N        1  まこぴす
# 10      500       \N        1    仙波
# 11      528       \N        1    仙波
# 12      693       \N        1  まこぴす
# 13      715       \N        1    仙波
# 14      746       \N        1  まこぴす
# 15      791       \N        1    仙波
# 16      813       \N        1  まこぴす
# 17      830      746        1     哲
# 18      831       \N        1    仙波
# 19      851      813        1     哲
# 20      888       \N        1    仙波
# 21      899       \N        1  まこぴす
# 22      916       \N        1    仙波
# 23      934      899        1     哲
# 24      964       \N        1  まこぴす
# 25      990       \N        1    仙波
# 26     1017       \N        1    \N
# 27     1031       \N        1  まこぴす
# 28     1048       \N        1    仙波
# 29     1066       \N        1     哲
# ...     ...      ...      ...   ...
# 9932   6241     6224    10001   まささ
# 9933   6243       \N    10001  オノヅカ
# 9934   6254       \N    10001  オノヅカ
# 9935   6257     6254    10001   まささ
# 9936   6264     6254    10001   みずき
# 9937   6266       \N    10001  オノヅカ
# 9938   6278     6266    10001   まささ
# 9939   6280     6266    10001   みずき
# 9940   6288       \N    10001  オノヅカ
# 9941   6326       \N    10001  オノヅカ
# 9942   6347       \N    10001   みずき
# 9943   6363       \N    10001   まささ
# 9944   6388       \N    10001  オノヅカ
# 9945   6397       \N    10001  オノヅカ
# 9946   6404     6388    10001   みずき
# 9947   6410     6404    10001  オノヅカ
# 9948   6415       \N    10001   まささ
# 9949   6419     6404    10001   まささ
# 9950   6435     6415    10001   みずき
# 9951   6436       \N    10001  オノヅカ
# 9952   6441     6436    10001   みずき
# 9953   6443     6436    10001   まささ
# 9954   6449       \N    10001  オノヅカ
# 9955   6451     6443    10001   みずき
# 9956   6459       \N    10001   みずき
# 9957   6463     6459    10001   まささ
# 9958   6467     6459    10001  オノヅカ
# 9959   6477       \N    10001  オノヅカ
# 9960   6491     6477    10001   まささ
# 9961   6521       \N    10001  オノヅカ
#
#                                                    body  \
# 0                                           よろしくお願いします！
# 1                                            よろしくお願いします
# 2                          名前なのが恥ずかしいです…\n\nよろしくお願いします！
# 3                                        早速課題やっちゃいましょう！
# 4                             やっちゃいましょう\n\nmoodleはゴミです！
# 5                                            使いにくいです(笑)
# 6                                                  同意です
# 7     以前インタラクティブアート受講していたのですが、その時に課題が不具合で出せなくなっていた時期...
# 8     学習環境として必要最低限の機能は備えていると思うが、操作性の面ではPCの最低限の知識があるこ...
# 9                                           自分の意見です！(笑)
# 10                                             ほぼほぼ同意です
# 11                                    他に何か考えてることなどありますか
# 12                                          他に意見ありますかー？
# 13                                              自分はないです
# 14                                            哲さんどうですか？
# 15                  まこびすさんがいい感じにまとめてくれたので自分はこれでいいと思います！
# 16                             １度共有テキスト全部消して現在の回答案書きます！
# 17                       > 哲さんどうですか？\n\n自分もみなさんの意見に同意です
# 18                                                 了解です
# 19                                           ありがとうございます
# 20                                    あざっす\n\nこれでいいのでは？
# 21                      こちらの回答案でよければ課題回答しちゃいますけど大丈夫ですか？
# 22                                              自分は平気です
# 23                                          よろしくお願いします！
# 24                                                完了です！
# 25                                              お疲れ様です！
# 26                                           １番乗りおめでとう！
# 27                                        ありがとうございます(笑)
# 28                                                  でた！
# 29                       お役に立てず申し訳ございません\n\nありがとうごいました！
# ...                                                 ...
# 9932               > 共有テキストの下半分のやつで出しちゃおうと思ってる\nわかりました！
# 9933                                       じゃあ提出しておきますね
# 9934                                             提出しました
# 9935                             > 提出しました\nありがとうございます！！
# 9936                              > 提出しました\nありがとうございます！
# 9937                                   共有テキスト一回消しちゃいます？
# 9938                        > 共有テキスト一回消しちゃいます？\nそうしましょう
# 9939           > 共有テキスト一回消しちゃいます？\nそうしましょう！で、課題2やりましょう！
# 9940             TinCanとは多種多様な学習活動の履歴を記録・検索・抽出するためのしすてむ
# 9941                        SCORMの次世代版でビッグデータにも対応してるらしい
# 9942  LMSに依存することなくあらゆる学習についての記録ができるため、さまざまな活用方法を期待する...
# 9943                               スマホアプリやタブレットでの利用もできる
# 9944                                    今出てきた意見全部繋げちゃう？
# 9945                                            あと位置づけか
# 9946                    > 今出てきた意見全部繋げちゃう？\n今つなげようとしてます！
# 9947   > &gt; 今出てきた意見全部繋げちゃう？\n\n> 今つなげようとしてます！\nお願いします
# 9948  次世代SCORMとして発表された規格で、正式名称はExperience API（略称：xAP...
# 9949  > &gt; 今出てきた意見全部繋げちゃう？\n\n> 今つなげようとしてます！\n\nあり...
# 9950  > 次世代SCORMとして発表された規格で、正式名称はExperience API（略称：x...
# 9951                                    共有テキストので良いと思います
# 9952                         > 共有テキストので良いと思います\n大丈夫ですか？
# 9953           > 共有テキストので良いと思います\n私もそう思います、分かりやすくていいです！
# 9954                                           提出お願いします
# 9955  > &gt; 共有テキストので良いと思います\n\n> 私もそう思います、分かりやすくていい...
# 9956                                         課題2提出完了です！
# 9957                          > 課題2提出完了です！\nありがとうございます！
# 9958                           > 課題2提出完了です！\nありがとうございます
# 9959                                           課題3やりますか
# 9960              > 課題3やりますか\nやりましょう、共有テキストいったん消しちゃいますね
# 9961                            「何を」の部分の選択肢が後1つくらい欲しいかな
#
#                         argument_a                    argument_b epistemic_a  \
# 0          non-argumentative moves       non-argumentative moves    off task
# 1          non-argumentative moves       non-argumentative moves    off task
# 2          non-argumentative moves       non-argumentative moves    off task
# 3          non-argumentative moves       non-argumentative moves    off task
# 4                     simple claim                  simple claim     on task
# 5                     simple claim                  simple claim     on task
# 6                     simple claim                  simple claim     on task
# 7                   grounded claim                grounded claim     on task
# 8     grounded and qualified claim  grounded and qualified claim     on task
# 9          non-argumentative moves                  simple claim    off task
# 10                    simple claim                  simple claim     on task
# 11         non-argumentative moves       non-argumentative moves     on task
# 12         non-argumentative moves       non-argumentative moves     on task
# 13         non-argumentative moves                  simple claim     on task
# 14         non-argumentative moves       non-argumentative moves     on task
# 15                  grounded claim                  simple claim     on task
# 16         non-argumentative moves       non-argumentative moves    off task
# 17                    simple claim                  simple claim     on task
# 18         non-argumentative moves                  simple claim     on task
# 19         non-argumentative moves                  simple claim    off task
# 20         non-argumentative moves                  simple claim    off task
# 21         non-argumentative moves       non-argumentative moves    off task
# 22         non-argumentative moves       non-argumentative moves    off task
# 23         non-argumentative moves       non-argumentative moves    off task
# 24         non-argumentative moves       non-argumentative moves    off task
# 25         non-argumentative moves       non-argumentative moves    off task
# 26         non-argumentative moves       non-argumentative moves    off task
# 27         non-argumentative moves       non-argumentative moves    off task
# 28         non-argumentative moves       non-argumentative moves    off task
# 29         non-argumentative moves       non-argumentative moves    off task
# ...                            ...                           ...         ...
# 9932       non-argumentative moves       non-argumentative moves    off task
# 9933       non-argumentative moves       non-argumentative moves    off task
# 9934       non-argumentative moves       non-argumentative moves    off task
# 9935       non-argumentative moves       non-argumentative moves    off task
# 9936       non-argumentative moves       non-argumentative moves    off task
# 9937       non-argumentative moves       non-argumentative moves    off task
# 9938       non-argumentative moves       non-argumentative moves    off task
# 9939       non-argumentative moves       non-argumentative moves    off task
# 9940                  simple claim                  simple claim     on task
# 9941                  simple claim                  simple claim     on task
# 9942                grounded claim                  simple claim     on task
# 9943                  simple claim                  simple claim     on task
# 9944       non-argumentative moves       non-argumentative moves    off task
# 9945                  simple claim       non-argumentative moves     on task
# 9946       non-argumentative moves       non-argumentative moves    off task
# 9947       non-argumentative moves       non-argumentative moves    off task
# 9948                  simple claim                  simple claim     on task
# 9949       non-argumentative moves       non-argumentative moves    off task
# 9950                  simple claim                  simple claim     on task
# 9951                  simple claim       non-argumentative moves     on task
# 9952       non-argumentative moves       non-argumentative moves     on task
# 9953                  simple claim       non-argumentative moves     on task
# 9954       non-argumentative moves       non-argumentative moves    off task
# 9955       non-argumentative moves       non-argumentative moves    off task
# 9956       non-argumentative moves       non-argumentative moves    off task
# 9957       non-argumentative moves       non-argumentative moves    off task
# 9958       non-argumentative moves       non-argumentative moves    off task
# 9959       non-argumentative moves       non-argumentative moves    off task
# 9960       non-argumentative moves       non-argumentative moves    off task
# 9961       non-argumentative moves       non-argumentative moves    off task
#
#      epistemic_b                  social_a                  social_b  \
# 0       off task                     blank                     blank
# 1       off task                     blank                     blank
# 2       off task                     blank                     blank
# 3       off task                     blank                     blank
# 4        on task           externalization                     blank
# 5        on task           externalization                     blank
# 6        on task  quick consensus building  quick consensus building
# 7        on task           externalization           externalization
# 8        on task           externalization           externalization
# 9        on task                     blank           externalization
# 10       on task  quick consensus building  quick consensus building
# 11       on task               elicitation               elicitation
# 12       on task               elicitation               elicitation
# 13       on task  quick consensus building           externalization
# 14      off task               elicitation                     blank
# 15       on task           externalization  quick consensus building
# 16      off task                     blank                     blank
# 17       on task  quick consensus building  quick consensus building
# 18       on task  quick consensus building  quick consensus building
# 19       on task                     blank  quick consensus building
# 20       on task                     blank  quick consensus building
# 21      off task                     blank                     blank
# 22      off task                     blank                     blank
# 23      off task                     blank                     blank
# 24      off task                     blank                     blank
# 25      off task                     blank                     blank
# 26      off task                     blank                     blank
# 27      off task                     blank                     blank
# 28      off task                     blank                     blank
# 29      off task                     blank                     blank
# ...          ...                       ...                       ...
# 9932    off task                     blank                     blank
# 9933    off task                     blank                     blank
# 9934    off task                     blank                     blank
# 9935    off task                     blank                     blank
# 9936    off task                     blank                     blank
# 9937    off task                     blank                     blank
# 9938    off task                     blank                     blank
# 9939    off task                     blank                     blank
# 9940     on task           externalization           externalization
# 9941     on task           externalization           externalization
# 9942     on task           externalization           externalization
# 9943     on task           externalization           externalization
# 9944    off task                     blank                     blank
# 9945    off task           externalization                     blank
# 9946    off task                     blank                     blank
# 9947    off task                     blank                     blank
# 9948     on task           externalization           externalization
# 9949    off task                     blank                     blank
# 9950     on task  quick consensus building  quick consensus building
# 9951    off task  quick consensus building                     blank
# 9952    off task               elicitation                     blank
# 9953    off task  quick consensus building                     blank
# 9954    off task                     blank                     blank
# 9955    off task                     blank                     blank
# 9956    off task                     blank                     blank
# 9957    off task                     blank                     blank
# 9958    off task                     blank                     blank
# 9959    off task                     blank                     blank
# 9960    off task                     blank                     blank
# 9961    off task                     blank                     blank
#
#               coordination_a          coordination_b
# 0                      blank                   blank
# 1                      blank                   blank
# 2                      blank                   blank
# 3                proceedings             proceedings
# 4                      blank                   blank
# 5                      blank                   blank
# 6                      blank                   blank
# 7                      blank                   blank
# 8                      blank                   blank
# 9                      blank                   blank
# 10                     blank                   blank
# 11                     blank                   blank
# 12                     blank                   blank
# 13                     blank                   blank
# 14                     blank             proceedings
# 15                     blank                   blank
# 16    technical coordination  technical coordination
# 17                     blank                   blank
# 18                     blank                   blank
# 19                     blank                   blank
# 20                     blank                   blank
# 21               proceedings  technical coordination
# 22                     blank                   blank
# 23                     blank                   blank
# 24    technical coordination  technical coordination
# 25                     blank                   blank
# 26                     blank                   blank
# 27                     blank                   blank
# 28                     blank                   blank
# 29                     blank                   blank
# ...                      ...                     ...
# 9932  technical coordination                   blank
# 9933  technical coordination  technical coordination
# 9934  technical coordination  technical coordination
# 9935                   blank                   blank
# 9936                   blank                   blank
# 9937  technical coordination  technical coordination
# 9938  technical coordination                   blank
# 9939             proceedings                   blank
# 9940                   blank                   blank
# 9941                   blank                   blank
# 9942                   blank                   blank
# 9943                   blank                   blank
# 9944             proceedings                   blank
# 9945                   blank                   blank
# 9946  technical coordination                   blank
# 9947  technical coordination                   blank
# 9948                   blank                   blank
# 9949  technical coordination                   blank
# 9950                   blank                   blank
# 9951                   blank                   blank
# 9952                   blank                   blank
# 9953                   blank                   blank
# 9954  technical coordination           task division
# 9955  technical coordination  technical coordination
# 9956  technical coordination  technical coordination
# 9957                   blank                   blank
# 9958                   blank                   blank
# 9959             proceedings             proceedings
# 9960  technical coordination  technical coordination
# 9961                   blank                   blank
#
# [9962 rows x 13 columns]

# %% [markdown]
# # スペルミスに対する処理
# socialのスペルミス　＝＞　integra[[[r]]]ion-oriented consensus building

# %%
print(Counter(All_df['social_a']))
print(Counter(All_df['social_b']), "\n")
dict_mis = {
    'integrarion-oriented consensus building':
    'integration-oriented consensus building'
}
All_df = All_df.replace({'social_a': dict_mis})
All_df = All_df.replace({'social_b': dict_mis})
print(Counter(All_df['social_a']))
print(Counter(All_df['social_b']))
# Out:
# Counter({'blank': 5713, 'externalization': 1917, 'quick consensus building': 1251, 'elicitation': 514, 'integrarion-oriented consensus building': 221, 'integration-oriented consensus building': 142, 'conflict-oriented consensus building': 122, 'summary': 82})
# Counter({'blank': 5572, 'externalization': 2061, 'quick consensus building': 1250, 'elicitation': 474, 'integrarion-oriented consensus building': 384, 'conflict-oriented consensus building': 170, 'summary': 51})
#
# Counter({'blank': 5713, 'externalization': 1917, 'quick consensus building': 1251, 'elicitation': 514, 'integration-oriented consensus building': 363, 'conflict-oriented consensus building': 122, 'summary': 82})
# Counter({'blank': 5572, 'externalization': 2061, 'quick consensus building': 1250, 'elicitation': 474, 'integration-oriented consensus building': 384, 'conflict-oriented consensus building': 170, 'summary': 51})

# %% [markdown]
# # 空白行を削除する

# %%
print(np.where(All_df.values[:, 0] == 'blank')[0])
print(All_df[All_df.values[:, 0] == 'blank'].values)

All_df = All_df[All_df['say_id'] != 'blank']

print(np.where(All_df.values[:, 0] == 'blank')[0])
# Out:
# [3498 3499 4944]
# [['blank' 'blank' 'blank' 'blank' 'blank' 'blank' 'blank' 'blank' 'blank'
#   'blank' 'blank' 'blank' 'blank']
#  ['blank' 'blank' 'blank' 'blank' 'blank' 'blank' 'blank' 'blank' 'blank'
#   'blank' 'blank' 'blank' 'blank']
#  ['blank' 'blank' 'blank' 'blank' 'blank' 'blank' 'blank' 'blank' 'blank'
#   'blank' 'blank' 'blank' 'blank']]
# []

# %% [markdown]
# # reply_idの\Nを-1に置換する

# %%
All_df = All_df.replace({'reply_id': {"\\N": -1}})
All_df
# Out:
#      say_id  reply_id group_id  name  \
# 0         1        -1        1  まこぴす
# 1        31        -1        1     哲
# 2        70        -1        1    仙波
# 3       119        -1        1  まこぴす
# 4       163        -1        1    仙波
# 5       194        -1        1  まこぴす
# 6       302        -1        1     哲
# 7       309        -1        1    仙波
# 8       385        -1        1  まこぴす
# 9       426        -1        1  まこぴす
# 10      500        -1        1    仙波
# 11      528        -1        1    仙波
# 12      693        -1        1  まこぴす
# 13      715        -1        1    仙波
# 14      746        -1        1  まこぴす
# 15      791        -1        1    仙波
# 16      813        -1        1  まこぴす
# 17      830       746        1     哲
# 18      831        -1        1    仙波
# 19      851       813        1     哲
# 20      888        -1        1    仙波
# 21      899        -1        1  まこぴす
# 22      916        -1        1    仙波
# 23      934       899        1     哲
# 24      964        -1        1  まこぴす
# 25      990        -1        1    仙波
# 26     1017        -1        1    \N
# 27     1031        -1        1  まこぴす
# 28     1048        -1        1    仙波
# 29     1066        -1        1     哲
# ...     ...       ...      ...   ...
# 9932   6241      6224    10001   まささ
# 9933   6243        -1    10001  オノヅカ
# 9934   6254        -1    10001  オノヅカ
# 9935   6257      6254    10001   まささ
# 9936   6264      6254    10001   みずき
# 9937   6266        -1    10001  オノヅカ
# 9938   6278      6266    10001   まささ
# 9939   6280      6266    10001   みずき
# 9940   6288        -1    10001  オノヅカ
# 9941   6326        -1    10001  オノヅカ
# 9942   6347        -1    10001   みずき
# 9943   6363        -1    10001   まささ
# 9944   6388        -1    10001  オノヅカ
# 9945   6397        -1    10001  オノヅカ
# 9946   6404      6388    10001   みずき
# 9947   6410      6404    10001  オノヅカ
# 9948   6415        -1    10001   まささ
# 9949   6419      6404    10001   まささ
# 9950   6435      6415    10001   みずき
# 9951   6436        -1    10001  オノヅカ
# 9952   6441      6436    10001   みずき
# 9953   6443      6436    10001   まささ
# 9954   6449        -1    10001  オノヅカ
# 9955   6451      6443    10001   みずき
# 9956   6459        -1    10001   みずき
# 9957   6463      6459    10001   まささ
# 9958   6467      6459    10001  オノヅカ
# 9959   6477        -1    10001  オノヅカ
# 9960   6491      6477    10001   まささ
# 9961   6521        -1    10001  オノヅカ
#
#                                                    body  \
# 0                                           よろしくお願いします！
# 1                                            よろしくお願いします
# 2                          名前なのが恥ずかしいです…\n\nよろしくお願いします！
# 3                                        早速課題やっちゃいましょう！
# 4                             やっちゃいましょう\n\nmoodleはゴミです！
# 5                                            使いにくいです(笑)
# 6                                                  同意です
# 7     以前インタラクティブアート受講していたのですが、その時に課題が不具合で出せなくなっていた時期...
# 8     学習環境として必要最低限の機能は備えていると思うが、操作性の面ではPCの最低限の知識があるこ...
# 9                                           自分の意見です！(笑)
# 10                                             ほぼほぼ同意です
# 11                                    他に何か考えてることなどありますか
# 12                                          他に意見ありますかー？
# 13                                              自分はないです
# 14                                            哲さんどうですか？
# 15                  まこびすさんがいい感じにまとめてくれたので自分はこれでいいと思います！
# 16                             １度共有テキスト全部消して現在の回答案書きます！
# 17                       > 哲さんどうですか？\n\n自分もみなさんの意見に同意です
# 18                                                 了解です
# 19                                           ありがとうございます
# 20                                    あざっす\n\nこれでいいのでは？
# 21                      こちらの回答案でよければ課題回答しちゃいますけど大丈夫ですか？
# 22                                              自分は平気です
# 23                                          よろしくお願いします！
# 24                                                完了です！
# 25                                              お疲れ様です！
# 26                                           １番乗りおめでとう！
# 27                                        ありがとうございます(笑)
# 28                                                  でた！
# 29                       お役に立てず申し訳ございません\n\nありがとうごいました！
# ...                                                 ...
# 9932               > 共有テキストの下半分のやつで出しちゃおうと思ってる\nわかりました！
# 9933                                       じゃあ提出しておきますね
# 9934                                             提出しました
# 9935                             > 提出しました\nありがとうございます！！
# 9936                              > 提出しました\nありがとうございます！
# 9937                                   共有テキスト一回消しちゃいます？
# 9938                        > 共有テキスト一回消しちゃいます？\nそうしましょう
# 9939           > 共有テキスト一回消しちゃいます？\nそうしましょう！で、課題2やりましょう！
# 9940             TinCanとは多種多様な学習活動の履歴を記録・検索・抽出するためのしすてむ
# 9941                        SCORMの次世代版でビッグデータにも対応してるらしい
# 9942  LMSに依存することなくあらゆる学習についての記録ができるため、さまざまな活用方法を期待する...
# 9943                               スマホアプリやタブレットでの利用もできる
# 9944                                    今出てきた意見全部繋げちゃう？
# 9945                                            あと位置づけか
# 9946                    > 今出てきた意見全部繋げちゃう？\n今つなげようとしてます！
# 9947   > &gt; 今出てきた意見全部繋げちゃう？\n\n> 今つなげようとしてます！\nお願いします
# 9948  次世代SCORMとして発表された規格で、正式名称はExperience API（略称：xAP...
# 9949  > &gt; 今出てきた意見全部繋げちゃう？\n\n> 今つなげようとしてます！\n\nあり...
# 9950  > 次世代SCORMとして発表された規格で、正式名称はExperience API（略称：x...
# 9951                                    共有テキストので良いと思います
# 9952                         > 共有テキストので良いと思います\n大丈夫ですか？
# 9953           > 共有テキストので良いと思います\n私もそう思います、分かりやすくていいです！
# 9954                                           提出お願いします
# 9955  > &gt; 共有テキストので良いと思います\n\n> 私もそう思います、分かりやすくていい...
# 9956                                         課題2提出完了です！
# 9957                          > 課題2提出完了です！\nありがとうございます！
# 9958                           > 課題2提出完了です！\nありがとうございます
# 9959                                           課題3やりますか
# 9960              > 課題3やりますか\nやりましょう、共有テキストいったん消しちゃいますね
# 9961                            「何を」の部分の選択肢が後1つくらい欲しいかな
#
#                         argument_a                    argument_b epistemic_a  \
# 0          non-argumentative moves       non-argumentative moves    off task
# 1          non-argumentative moves       non-argumentative moves    off task
# 2          non-argumentative moves       non-argumentative moves    off task
# 3          non-argumentative moves       non-argumentative moves    off task
# 4                     simple claim                  simple claim     on task
# 5                     simple claim                  simple claim     on task
# 6                     simple claim                  simple claim     on task
# 7                   grounded claim                grounded claim     on task
# 8     grounded and qualified claim  grounded and qualified claim     on task
# 9          non-argumentative moves                  simple claim    off task
# 10                    simple claim                  simple claim     on task
# 11         non-argumentative moves       non-argumentative moves     on task
# 12         non-argumentative moves       non-argumentative moves     on task
# 13         non-argumentative moves                  simple claim     on task
# 14         non-argumentative moves       non-argumentative moves     on task
# 15                  grounded claim                  simple claim     on task
# 16         non-argumentative moves       non-argumentative moves    off task
# 17                    simple claim                  simple claim     on task
# 18         non-argumentative moves                  simple claim     on task
# 19         non-argumentative moves                  simple claim    off task
# 20         non-argumentative moves                  simple claim    off task
# 21         non-argumentative moves       non-argumentative moves    off task
# 22         non-argumentative moves       non-argumentative moves    off task
# 23         non-argumentative moves       non-argumentative moves    off task
# 24         non-argumentative moves       non-argumentative moves    off task
# 25         non-argumentative moves       non-argumentative moves    off task
# 26         non-argumentative moves       non-argumentative moves    off task
# 27         non-argumentative moves       non-argumentative moves    off task
# 28         non-argumentative moves       non-argumentative moves    off task
# 29         non-argumentative moves       non-argumentative moves    off task
# ...                            ...                           ...         ...
# 9932       non-argumentative moves       non-argumentative moves    off task
# 9933       non-argumentative moves       non-argumentative moves    off task
# 9934       non-argumentative moves       non-argumentative moves    off task
# 9935       non-argumentative moves       non-argumentative moves    off task
# 9936       non-argumentative moves       non-argumentative moves    off task
# 9937       non-argumentative moves       non-argumentative moves    off task
# 9938       non-argumentative moves       non-argumentative moves    off task
# 9939       non-argumentative moves       non-argumentative moves    off task
# 9940                  simple claim                  simple claim     on task
# 9941                  simple claim                  simple claim     on task
# 9942                grounded claim                  simple claim     on task
# 9943                  simple claim                  simple claim     on task
# 9944       non-argumentative moves       non-argumentative moves    off task
# 9945                  simple claim       non-argumentative moves     on task
# 9946       non-argumentative moves       non-argumentative moves    off task
# 9947       non-argumentative moves       non-argumentative moves    off task
# 9948                  simple claim                  simple claim     on task
# 9949       non-argumentative moves       non-argumentative moves    off task
# 9950                  simple claim                  simple claim     on task
# 9951                  simple claim       non-argumentative moves     on task
# 9952       non-argumentative moves       non-argumentative moves     on task
# 9953                  simple claim       non-argumentative moves     on task
# 9954       non-argumentative moves       non-argumentative moves    off task
# 9955       non-argumentative moves       non-argumentative moves    off task
# 9956       non-argumentative moves       non-argumentative moves    off task
# 9957       non-argumentative moves       non-argumentative moves    off task
# 9958       non-argumentative moves       non-argumentative moves    off task
# 9959       non-argumentative moves       non-argumentative moves    off task
# 9960       non-argumentative moves       non-argumentative moves    off task
# 9961       non-argumentative moves       non-argumentative moves    off task
#
#      epistemic_b                  social_a                  social_b  \
# 0       off task                     blank                     blank
# 1       off task                     blank                     blank
# 2       off task                     blank                     blank
# 3       off task                     blank                     blank
# 4        on task           externalization                     blank
# 5        on task           externalization                     blank
# 6        on task  quick consensus building  quick consensus building
# 7        on task           externalization           externalization
# 8        on task           externalization           externalization
# 9        on task                     blank           externalization
# 10       on task  quick consensus building  quick consensus building
# 11       on task               elicitation               elicitation
# 12       on task               elicitation               elicitation
# 13       on task  quick consensus building           externalization
# 14      off task               elicitation                     blank
# 15       on task           externalization  quick consensus building
# 16      off task                     blank                     blank
# 17       on task  quick consensus building  quick consensus building
# 18       on task  quick consensus building  quick consensus building
# 19       on task                     blank  quick consensus building
# 20       on task                     blank  quick consensus building
# 21      off task                     blank                     blank
# 22      off task                     blank                     blank
# 23      off task                     blank                     blank
# 24      off task                     blank                     blank
# 25      off task                     blank                     blank
# 26      off task                     blank                     blank
# 27      off task                     blank                     blank
# 28      off task                     blank                     blank
# 29      off task                     blank                     blank
# ...          ...                       ...                       ...
# 9932    off task                     blank                     blank
# 9933    off task                     blank                     blank
# 9934    off task                     blank                     blank
# 9935    off task                     blank                     blank
# 9936    off task                     blank                     blank
# 9937    off task                     blank                     blank
# 9938    off task                     blank                     blank
# 9939    off task                     blank                     blank
# 9940     on task           externalization           externalization
# 9941     on task           externalization           externalization
# 9942     on task           externalization           externalization
# 9943     on task           externalization           externalization
# 9944    off task                     blank                     blank
# 9945    off task           externalization                     blank
# 9946    off task                     blank                     blank
# 9947    off task                     blank                     blank
# 9948     on task           externalization           externalization
# 9949    off task                     blank                     blank
# 9950     on task  quick consensus building  quick consensus building
# 9951    off task  quick consensus building                     blank
# 9952    off task               elicitation                     blank
# 9953    off task  quick consensus building                     blank
# 9954    off task                     blank                     blank
# 9955    off task                     blank                     blank
# 9956    off task                     blank                     blank
# 9957    off task                     blank                     blank
# 9958    off task                     blank                     blank
# 9959    off task                     blank                     blank
# 9960    off task                     blank                     blank
# 9961    off task                     blank                     blank
#
#               coordination_a          coordination_b
# 0                      blank                   blank
# 1                      blank                   blank
# 2                      blank                   blank
# 3                proceedings             proceedings
# 4                      blank                   blank
# 5                      blank                   blank
# 6                      blank                   blank
# 7                      blank                   blank
# 8                      blank                   blank
# 9                      blank                   blank
# 10                     blank                   blank
# 11                     blank                   blank
# 12                     blank                   blank
# 13                     blank                   blank
# 14                     blank             proceedings
# 15                     blank                   blank
# 16    technical coordination  technical coordination
# 17                     blank                   blank
# 18                     blank                   blank
# 19                     blank                   blank
# 20                     blank                   blank
# 21               proceedings  technical coordination
# 22                     blank                   blank
# 23                     blank                   blank
# 24    technical coordination  technical coordination
# 25                     blank                   blank
# 26                     blank                   blank
# 27                     blank                   blank
# 28                     blank                   blank
# 29                     blank                   blank
# ...                      ...                     ...
# 9932  technical coordination                   blank
# 9933  technical coordination  technical coordination
# 9934  technical coordination  technical coordination
# 9935                   blank                   blank
# 9936                   blank                   blank
# 9937  technical coordination  technical coordination
# 9938  technical coordination                   blank
# 9939             proceedings                   blank
# 9940                   blank                   blank
# 9941                   blank                   blank
# 9942                   blank                   blank
# 9943                   blank                   blank
# 9944             proceedings                   blank
# 9945                   blank                   blank
# 9946  technical coordination                   blank
# 9947  technical coordination                   blank
# 9948                   blank                   blank
# 9949  technical coordination                   blank
# 9950                   blank                   blank
# 9951                   blank                   blank
# 9952                   blank                   blank
# 9953                   blank                   blank
# 9954  technical coordination           task division
# 9955  technical coordination  technical coordination
# 9956  technical coordination  technical coordination
# 9957                   blank                   blank
# 9958                   blank                   blank
# 9959             proceedings             proceedings
# 9960  technical coordination  technical coordination
# 9961                   blank                   blank
#
# [9959 rows x 13 columns]

# %% [markdown]
# # say_id、reply_idとgroup_idの型をstr型に統一する

# %%
print(type(All_df['say_id'][0]))
print(type(All_df['reply_id'][0]))
print(type(All_df['group_id'][0]), "\n")
All_df['say_id'] = All_df['say_id'].apply(int).apply(str)
All_df['reply_id'] = All_df['reply_id'].apply(int).apply(str)
All_df['group_id'] = All_df['group_id'].apply(int).apply(str)
All_df['name'] = All_df['name'].apply(str)
All_df['body'] = All_df['body'].apply(str)
print(type(All_df['say_id'][0]))
print(type(All_df['reply_id'][0]))
print(type(All_df['group_id'][0]))
All_df
# Out:
# <class 'float'>
# <class 'numpy.int64'>
# <class 'float'>
#
# <class 'str'>
# <class 'str'>
# <class 'str'>
#      say_id reply_id group_id  name  \
# 0         1       -1        1  まこぴす
# 1        31       -1        1     哲
# 2        70       -1        1    仙波
# 3       119       -1        1  まこぴす
# 4       163       -1        1    仙波
# 5       194       -1        1  まこぴす
# 6       302       -1        1     哲
# 7       309       -1        1    仙波
# 8       385       -1        1  まこぴす
# 9       426       -1        1  まこぴす
# 10      500       -1        1    仙波
# 11      528       -1        1    仙波
# 12      693       -1        1  まこぴす
# 13      715       -1        1    仙波
# 14      746       -1        1  まこぴす
# 15      791       -1        1    仙波
# 16      813       -1        1  まこぴす
# 17      830      746        1     哲
# 18      831       -1        1    仙波
# 19      851      813        1     哲
# 20      888       -1        1    仙波
# 21      899       -1        1  まこぴす
# 22      916       -1        1    仙波
# 23      934      899        1     哲
# 24      964       -1        1  まこぴす
# 25      990       -1        1    仙波
# 26     1017       -1        1    \N
# 27     1031       -1        1  まこぴす
# 28     1048       -1        1    仙波
# 29     1066       -1        1     哲
# ...     ...      ...      ...   ...
# 9932   6241     6224    10001   まささ
# 9933   6243       -1    10001  オノヅカ
# 9934   6254       -1    10001  オノヅカ
# 9935   6257     6254    10001   まささ
# 9936   6264     6254    10001   みずき
# 9937   6266       -1    10001  オノヅカ
# 9938   6278     6266    10001   まささ
# 9939   6280     6266    10001   みずき
# 9940   6288       -1    10001  オノヅカ
# 9941   6326       -1    10001  オノヅカ
# 9942   6347       -1    10001   みずき
# 9943   6363       -1    10001   まささ
# 9944   6388       -1    10001  オノヅカ
# 9945   6397       -1    10001  オノヅカ
# 9946   6404     6388    10001   みずき
# 9947   6410     6404    10001  オノヅカ
# 9948   6415       -1    10001   まささ
# 9949   6419     6404    10001   まささ
# 9950   6435     6415    10001   みずき
# 9951   6436       -1    10001  オノヅカ
# 9952   6441     6436    10001   みずき
# 9953   6443     6436    10001   まささ
# 9954   6449       -1    10001  オノヅカ
# 9955   6451     6443    10001   みずき
# 9956   6459       -1    10001   みずき
# 9957   6463     6459    10001   まささ
# 9958   6467     6459    10001  オノヅカ
# 9959   6477       -1    10001  オノヅカ
# 9960   6491     6477    10001   まささ
# 9961   6521       -1    10001  オノヅカ
#
#                                                    body  \
# 0                                           よろしくお願いします！
# 1                                            よろしくお願いします
# 2                          名前なのが恥ずかしいです…\n\nよろしくお願いします！
# 3                                        早速課題やっちゃいましょう！
# 4                             やっちゃいましょう\n\nmoodleはゴミです！
# 5                                            使いにくいです(笑)
# 6                                                  同意です
# 7     以前インタラクティブアート受講していたのですが、その時に課題が不具合で出せなくなっていた時期...
# 8     学習環境として必要最低限の機能は備えていると思うが、操作性の面ではPCの最低限の知識があるこ...
# 9                                           自分の意見です！(笑)
# 10                                             ほぼほぼ同意です
# 11                                    他に何か考えてることなどありますか
# 12                                          他に意見ありますかー？
# 13                                              自分はないです
# 14                                            哲さんどうですか？
# 15                  まこびすさんがいい感じにまとめてくれたので自分はこれでいいと思います！
# 16                             １度共有テキスト全部消して現在の回答案書きます！
# 17                       > 哲さんどうですか？\n\n自分もみなさんの意見に同意です
# 18                                                 了解です
# 19                                           ありがとうございます
# 20                                    あざっす\n\nこれでいいのでは？
# 21                      こちらの回答案でよければ課題回答しちゃいますけど大丈夫ですか？
# 22                                              自分は平気です
# 23                                          よろしくお願いします！
# 24                                                完了です！
# 25                                              お疲れ様です！
# 26                                           １番乗りおめでとう！
# 27                                        ありがとうございます(笑)
# 28                                                  でた！
# 29                       お役に立てず申し訳ございません\n\nありがとうごいました！
# ...                                                 ...
# 9932               > 共有テキストの下半分のやつで出しちゃおうと思ってる\nわかりました！
# 9933                                       じゃあ提出しておきますね
# 9934                                             提出しました
# 9935                             > 提出しました\nありがとうございます！！
# 9936                              > 提出しました\nありがとうございます！
# 9937                                   共有テキスト一回消しちゃいます？
# 9938                        > 共有テキスト一回消しちゃいます？\nそうしましょう
# 9939           > 共有テキスト一回消しちゃいます？\nそうしましょう！で、課題2やりましょう！
# 9940             TinCanとは多種多様な学習活動の履歴を記録・検索・抽出するためのしすてむ
# 9941                        SCORMの次世代版でビッグデータにも対応してるらしい
# 9942  LMSに依存することなくあらゆる学習についての記録ができるため、さまざまな活用方法を期待する...
# 9943                               スマホアプリやタブレットでの利用もできる
# 9944                                    今出てきた意見全部繋げちゃう？
# 9945                                            あと位置づけか
# 9946                    > 今出てきた意見全部繋げちゃう？\n今つなげようとしてます！
# 9947   > &gt; 今出てきた意見全部繋げちゃう？\n\n> 今つなげようとしてます！\nお願いします
# 9948  次世代SCORMとして発表された規格で、正式名称はExperience API（略称：xAP...
# 9949  > &gt; 今出てきた意見全部繋げちゃう？\n\n> 今つなげようとしてます！\n\nあり...
# 9950  > 次世代SCORMとして発表された規格で、正式名称はExperience API（略称：x...
# 9951                                    共有テキストので良いと思います
# 9952                         > 共有テキストので良いと思います\n大丈夫ですか？
# 9953           > 共有テキストので良いと思います\n私もそう思います、分かりやすくていいです！
# 9954                                           提出お願いします
# 9955  > &gt; 共有テキストので良いと思います\n\n> 私もそう思います、分かりやすくていい...
# 9956                                         課題2提出完了です！
# 9957                          > 課題2提出完了です！\nありがとうございます！
# 9958                           > 課題2提出完了です！\nありがとうございます
# 9959                                           課題3やりますか
# 9960              > 課題3やりますか\nやりましょう、共有テキストいったん消しちゃいますね
# 9961                            「何を」の部分の選択肢が後1つくらい欲しいかな
#
#                         argument_a                    argument_b epistemic_a  \
# 0          non-argumentative moves       non-argumentative moves    off task
# 1          non-argumentative moves       non-argumentative moves    off task
# 2          non-argumentative moves       non-argumentative moves    off task
# 3          non-argumentative moves       non-argumentative moves    off task
# 4                     simple claim                  simple claim     on task
# 5                     simple claim                  simple claim     on task
# 6                     simple claim                  simple claim     on task
# 7                   grounded claim                grounded claim     on task
# 8     grounded and qualified claim  grounded and qualified claim     on task
# 9          non-argumentative moves                  simple claim    off task
# 10                    simple claim                  simple claim     on task
# 11         non-argumentative moves       non-argumentative moves     on task
# 12         non-argumentative moves       non-argumentative moves     on task
# 13         non-argumentative moves                  simple claim     on task
# 14         non-argumentative moves       non-argumentative moves     on task
# 15                  grounded claim                  simple claim     on task
# 16         non-argumentative moves       non-argumentative moves    off task
# 17                    simple claim                  simple claim     on task
# 18         non-argumentative moves                  simple claim     on task
# 19         non-argumentative moves                  simple claim    off task
# 20         non-argumentative moves                  simple claim    off task
# 21         non-argumentative moves       non-argumentative moves    off task
# 22         non-argumentative moves       non-argumentative moves    off task
# 23         non-argumentative moves       non-argumentative moves    off task
# 24         non-argumentative moves       non-argumentative moves    off task
# 25         non-argumentative moves       non-argumentative moves    off task
# 26         non-argumentative moves       non-argumentative moves    off task
# 27         non-argumentative moves       non-argumentative moves    off task
# 28         non-argumentative moves       non-argumentative moves    off task
# 29         non-argumentative moves       non-argumentative moves    off task
# ...                            ...                           ...         ...
# 9932       non-argumentative moves       non-argumentative moves    off task
# 9933       non-argumentative moves       non-argumentative moves    off task
# 9934       non-argumentative moves       non-argumentative moves    off task
# 9935       non-argumentative moves       non-argumentative moves    off task
# 9936       non-argumentative moves       non-argumentative moves    off task
# 9937       non-argumentative moves       non-argumentative moves    off task
# 9938       non-argumentative moves       non-argumentative moves    off task
# 9939       non-argumentative moves       non-argumentative moves    off task
# 9940                  simple claim                  simple claim     on task
# 9941                  simple claim                  simple claim     on task
# 9942                grounded claim                  simple claim     on task
# 9943                  simple claim                  simple claim     on task
# 9944       non-argumentative moves       non-argumentative moves    off task
# 9945                  simple claim       non-argumentative moves     on task
# 9946       non-argumentative moves       non-argumentative moves    off task
# 9947       non-argumentative moves       non-argumentative moves    off task
# 9948                  simple claim                  simple claim     on task
# 9949       non-argumentative moves       non-argumentative moves    off task
# 9950                  simple claim                  simple claim     on task
# 9951                  simple claim       non-argumentative moves     on task
# 9952       non-argumentative moves       non-argumentative moves     on task
# 9953                  simple claim       non-argumentative moves     on task
# 9954       non-argumentative moves       non-argumentative moves    off task
# 9955       non-argumentative moves       non-argumentative moves    off task
# 9956       non-argumentative moves       non-argumentative moves    off task
# 9957       non-argumentative moves       non-argumentative moves    off task
# 9958       non-argumentative moves       non-argumentative moves    off task
# 9959       non-argumentative moves       non-argumentative moves    off task
# 9960       non-argumentative moves       non-argumentative moves    off task
# 9961       non-argumentative moves       non-argumentative moves    off task
#
#      epistemic_b                  social_a                  social_b  \
# 0       off task                     blank                     blank
# 1       off task                     blank                     blank
# 2       off task                     blank                     blank
# 3       off task                     blank                     blank
# 4        on task           externalization                     blank
# 5        on task           externalization                     blank
# 6        on task  quick consensus building  quick consensus building
# 7        on task           externalization           externalization
# 8        on task           externalization           externalization
# 9        on task                     blank           externalization
# 10       on task  quick consensus building  quick consensus building
# 11       on task               elicitation               elicitation
# 12       on task               elicitation               elicitation
# 13       on task  quick consensus building           externalization
# 14      off task               elicitation                     blank
# 15       on task           externalization  quick consensus building
# 16      off task                     blank                     blank
# 17       on task  quick consensus building  quick consensus building
# 18       on task  quick consensus building  quick consensus building
# 19       on task                     blank  quick consensus building
# 20       on task                     blank  quick consensus building
# 21      off task                     blank                     blank
# 22      off task                     blank                     blank
# 23      off task                     blank                     blank
# 24      off task                     blank                     blank
# 25      off task                     blank                     blank
# 26      off task                     blank                     blank
# 27      off task                     blank                     blank
# 28      off task                     blank                     blank
# 29      off task                     blank                     blank
# ...          ...                       ...                       ...
# 9932    off task                     blank                     blank
# 9933    off task                     blank                     blank
# 9934    off task                     blank                     blank
# 9935    off task                     blank                     blank
# 9936    off task                     blank                     blank
# 9937    off task                     blank                     blank
# 9938    off task                     blank                     blank
# 9939    off task                     blank                     blank
# 9940     on task           externalization           externalization
# 9941     on task           externalization           externalization
# 9942     on task           externalization           externalization
# 9943     on task           externalization           externalization
# 9944    off task                     blank                     blank
# 9945    off task           externalization                     blank
# 9946    off task                     blank                     blank
# 9947    off task                     blank                     blank
# 9948     on task           externalization           externalization
# 9949    off task                     blank                     blank
# 9950     on task  quick consensus building  quick consensus building
# 9951    off task  quick consensus building                     blank
# 9952    off task               elicitation                     blank
# 9953    off task  quick consensus building                     blank
# 9954    off task                     blank                     blank
# 9955    off task                     blank                     blank
# 9956    off task                     blank                     blank
# 9957    off task                     blank                     blank
# 9958    off task                     blank                     blank
# 9959    off task                     blank                     blank
# 9960    off task                     blank                     blank
# 9961    off task                     blank                     blank
#
#               coordination_a          coordination_b
# 0                      blank                   blank
# 1                      blank                   blank
# 2                      blank                   blank
# 3                proceedings             proceedings
# 4                      blank                   blank
# 5                      blank                   blank
# 6                      blank                   blank
# 7                      blank                   blank
# 8                      blank                   blank
# 9                      blank                   blank
# 10                     blank                   blank
# 11                     blank                   blank
# 12                     blank                   blank
# 13                     blank                   blank
# 14                     blank             proceedings
# 15                     blank                   blank
# 16    technical coordination  technical coordination
# 17                     blank                   blank
# 18                     blank                   blank
# 19                     blank                   blank
# 20                     blank                   blank
# 21               proceedings  technical coordination
# 22                     blank                   blank
# 23                     blank                   blank
# 24    technical coordination  technical coordination
# 25                     blank                   blank
# 26                     blank                   blank
# 27                     blank                   blank
# 28                     blank                   blank
# 29                     blank                   blank
# ...                      ...                     ...
# 9932  technical coordination                   blank
# 9933  technical coordination  technical coordination
# 9934  technical coordination  technical coordination
# 9935                   blank                   blank
# 9936                   blank                   blank
# 9937  technical coordination  technical coordination
# 9938  technical coordination                   blank
# 9939             proceedings                   blank
# 9940                   blank                   blank
# 9941                   blank                   blank
# 9942                   blank                   blank
# 9943                   blank                   blank
# 9944             proceedings                   blank
# 9945                   blank                   blank
# 9946  technical coordination                   blank
# 9947  technical coordination                   blank
# 9948                   blank                   blank
# 9949  technical coordination                   blank
# 9950                   blank                   blank
# 9951                   blank                   blank
# 9952                   blank                   blank
# 9953                   blank                   blank
# 9954  technical coordination           task division
# 9955  technical coordination  technical coordination
# 9956  technical coordination  technical coordination
# 9957                   blank                   blank
# 9958                   blank                   blank
# 9959             proceedings             proceedings
# 9960  technical coordination  technical coordination
# 9961                   blank                   blank
#
# [9959 rows x 13 columns]

# %%
# 特別対応（マージするために）
print(All_df.values[8266])
All_df = All_df.replace('\x08SU', '_x0008_SU')
print(All_df.values[8266])
# Out:
# ['4916' '4915' '1' '\x08SU' '> 英語わかんね＾ｑ＾\nおなじく＾ｑ＾'
#  'non-argumentative moves' 'non-argumentative moves' 'off task' 'off task'
#  'blank' 'blank' 'blank' 'blank']
# ['4916' '4915' '1' '_x0008_SU' '> 英語わかんね＾ｑ＾\nおなじく＾ｑ＾'
#  'non-argumentative moves' 'non-argumentative moves' 'off task' 'off task'
#  'blank' 'blank' 'blank' 'blank']

# %%
[print(c, ":", Counter(All_df[c]), '\n') for c in col_p]
# Out:
# argument_a : Counter({'non-argumentative moves': 5804, 'simple claim': 3204, 'grounded claim': 509, 'blank': 299, 'qualified claim': 120, 'grounded and qualified claim': 23})
#
# argument_b : Counter({'non-argumentative moves': 5567, 'simple claim': 3501, 'blank': 434, 'grounded claim': 382, 'qualified claim': 61, 'grounded and qualified claim': 14})
#
# epistemic_a : Counter({'off task': 5244, 'on task': 4415, 'no sense': 299, 'blank': 1})
#
# epistemic_b : Counter({'off task': 5223, 'on task': 4409, 'no sense': 323, 'blank': 4})
#
# social_a : Counter({'blank': 5710, 'externalization': 1917, 'quick consensus building': 1251, 'elicitation': 514, 'integration-oriented consensus building': 363, 'conflict-oriented consensus building': 122, 'summary': 82})
#
# social_b : Counter({'blank': 5569, 'externalization': 2061, 'quick consensus building': 1250, 'elicitation': 474, 'integration-oriented consensus building': 384, 'conflict-oriented consensus building': 170, 'summary': 51})
#
# coordination_a : Counter({'blank': 7533, 'technical coordination': 1609, 'proceedings': 501, 'task division': 178, 'time management': 91, 'quote': 47})
#
# coordination_b : Counter({'blank': 8479, 'technical coordination': 926, 'proceedings': 339, 'task division': 89, 'time management': 86, 'quote': 40})
# [None, None, None, None, None, None, None, None]

# %% [markdown]
# # indexを連番に振り直す

# %%
All_df_r = All_df.reset_index(drop=True)

# %% [markdown]
# # フィアルに保存する

# %%
excel_writer = pd.ExcelWriter(
    "../data/5dimensions.xlsx",
    engine='xlsxwriter',
    options={'strings_to_urls': False})
All_df_r.to_excel(excel_writer, "sheet1")
excel_writer.save()
All_df_r.to_pickle("../data/5dimensions.pickle")
